# %% [markdown]
# # Wokflow  **ZLightGBM** para competencia 3

# %% [markdown]
# Este workflow hace la predicción final en 202109 con un corte de undersampling de 0.05 entrenando desde 201901 hasta 202107, descartando 201910 y 202006

# %% [markdown]
# ## Inicializacion

# %%
# limpio la memoria
Sys.time()
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
# [1] "2025-12-03 23:19:37 UTC"
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  657982 35.2 1454660    77.7 1355011  72.4
# Vcells 1221409  9.4 8388608    64.0 1975153  15.1

# %%
PARAM <- list()
PARAM$experimento <- "e010_03"
PARAM$semilla_primigenia <- 100343

# %%
setwd("/content/buckets/b1/exp")
experimento_folder <- PARAM$experimento
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ### Generacion de la clase_ternaria

# %%
Sys.time()
require("data.table")

# leo los dos datasets y los uno
dataset_02 <- fread("~/buckets/b1/datasets/competencia_02_crudo.csv.gz")
dataset_03 <- fread("~/buckets/b1/datasets/competencia_03_crudo.csv.gz")

# los apilo uno debajo del otro
dataset <- rbindlist(
  list(dataset_02, dataset_03),
  use.names = TRUE,  
  fill = TRUE        
)

rm(dataset_02, dataset_03)
gc()

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
  "pos" = .I,
  numero_de_cliente,
  periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 )
]

# ordeno
setorder(dsimple, numero_de_cliente, periodo0)

# calculo topes
periodo_ultimo    <- dsimple[, max(periodo0)]
periodo_anteultimo <- periodo_ultimo - 1

# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
  shift(periodo0, n = 1:2, fill = NA, type = "lead"), by = numero_de_cliente
]

dsimple[periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA"]

# calculo BAJA+1
dsimple[periodo0 < periodo_ultimo &
          (is.na(periodo1) | periodo0 + 1 < periodo1),
        clase_ternaria := "BAJA+1"
]

# calculo BAJA+2
dsimple[periodo0 < periodo_anteultimo & (periodo0 + 1 == periodo1) &
          (is.na(periodo2) | periodo0 + 2 < periodo2),
        clase_ternaria := "BAJA+2"
]

# pego el resultado en el dataset original y grabo
setorder(dsimple, pos)
dataset[, clase_ternaria := dsimple$clase_ternaria]

rm(dsimple)
gc()
Sys.time()
# Out:
# [1] "2025-12-03 23:19:45 UTC"
# Loading required package: data.table
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells    758333   40.5    1454660    77.7    1454660   77.7
# Vcells 555645391 4239.3 1481535975 11303.3 1296634162 9892.6
#        used      (Mb)   gc trigger (Mb)    max used   (Mb)
# Ncells    767203   41.0    1454660    77.7    1454660   77.7
# Vcells 560570692 4276.9 1481535975 11303.3 1296634162 9892.6
# [1] "2025-12-03 23:20:05 UTC"

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  201901   BAJA+1            645
# 2  201901   BAJA+2            729
# 3  201901   CONTINUA       122899
# 4  201902   BAJA+1            733
# 5  201902   BAJA+2            707
# 6  201902   CONTINUA       123961
# 7  201903   BAJA+1            708
# 8  201903   BAJA+2            751
# 9  201903   CONTINUA       124508
# 10 201904   BAJA+1            756
# 11 201904   BAJA+2            514
# 12 201904   CONTINUA       125268
# 13 201905   BAJA+1            517
# 14 201905   BAJA+2            692
# 15 201905   CONTINUA       125993
# 16 201906   BAJA+1            696
# 17 201906   BAJA+2            608
# 18 201906   CONTINUA       127430
# 19 201907   BAJA+1            611
# 20 201907   BAJA+2            680
# 21 201907   CONTINUA       128977
# 22 201908   BAJA+1            683
# 23 201908   BAJA+2            577
# 24 201908   CONTINUA       130883
# 25 201909   BAJA+1            581
# 26 201909   BAJA+2            582
# 27 201909   CONTINUA       132594
# 28 201910   BAJA+1            594
# 29 201910   BAJA+2            618
# 30 201910   CONTINUA       134798
# ⋮  ⋮        ⋮              ⋮
# 67 202011   BAJA+1            456
# 68 202011   BAJA+2            616
# 69 202011   CONTINUA       159178
# 70 202012   BAJA+1            622
# 71 202012   BAJA+2            619
# 72 202012   CONTINUA       159756
# 73 202101   BAJA+1            622
# 74 202101   BAJA+2            825
# 75 202101   CONTINUA       160080
# 76 202102   BAJA+1            831
# 77 202102   BAJA+2           1032
# 78 202102   CONTINUA       160292
# 79 202103   BAJA+1           1039
# 80 202103   BAJA+2            951
# 81 202103   CONTINUA       161119
# 82 202104   BAJA+1            955
# 83 202104   BAJA+2           1130
# 84 202104   CONTINUA       161333
# 85 202105   BAJA+1           1134
# 86 202105   BAJA+2            842
# 87 202105   CONTINUA       161941
# 88 202106   BAJA+1            843
# 89 202106   BAJA+2           1134
# 90 202106   CONTINUA       162336
# 91 202107   BAJA+1           1137
# 92 202107   BAJA+2           1248
# 93 202107   CONTINUA       162211
# 94 202108   NA             163570
# 95 202108   BAJA+1           1252
# 96 202109   NA             165093

# %% [markdown]
# ### Eliminacion de Features

# %%
# Variables rotas
dataset[, mprestamos_personales := NULL ]
dataset[, cprestamos_personales := NULL ]

# %% [markdown]
# ### Data Quality

# %% [markdown]
# Para los meses identificados donde para una variable todos sus valores son ceros, se aplica interpolación utilizando el mes previo y el posterior

# %%
library(DBI)
library(duckdb)
library(data.table)

con <- dbConnect(duckdb(), dbdir=":memory:")

corregir_interpolar <- function(dataset, campo, meses) {
  # Por si dataset viene con basura previa:
  # borramos v1, v2, promedio si existieran
  cols_tmp <- intersect(c("v1", "v2", "promedio"), names(dataset))
  if (length(cols_tmp) > 0) {
    dataset[, (cols_tmp) := NULL]
  }

  # Subo el dataset a DuckDB
  dbWriteTable(con, "tmp", dataset, overwrite = TRUE)

  meses_str <- paste(meses, collapse = ", ")

  query <- paste0("
    WITH base AS (
        SELECT
            *,
            lag(", campo, ") OVER (
                PARTITION BY numero_de_cliente
                ORDER BY foto_mes
            ) AS v1,
            lead(", campo, ") OVER (
                PARTITION BY numero_de_cliente
                ORDER BY foto_mes
            ) AS v2
        FROM tmp
    ),
    calc AS (
        SELECT
            *,
            CASE
                WHEN v1 IS NOT NULL AND v2 IS NOT NULL THEN (v1 + v2) / 2.0
                WHEN v1 IS NOT NULL THEN v1
                WHEN v2 IS NOT NULL THEN v2
                ELSE NULL
            END AS promedio
        FROM base
    )
    SELECT
        * EXCLUDE(v1, v2, promedio)
        REPLACE(
            CASE
                WHEN foto_mes IN (", meses_str, ") THEN promedio
                ELSE ", campo, "
            END AS ", campo, "
        )
    FROM calc
  ")

  result <- dbGetQuery(con, query)
  return(as.data.table(result))
}

# %%
# Campos que voy a arreglar sin 201910 y 202006
atributos_y_meses <- list(
  list(campo = "ctarjeta_visa_debitos_automaticos", meses = c(201904)),
  list(campo = "mttarjeta_visa_debitos_automaticos", meses = c(201904)),
  list(campo = "mrentabilidad", meses = c(201905)),
  list(campo = "mrentabilidad_annual", meses = c(201905)),
  list(campo = "mcomisiones", meses = c(201905)),
  list(campo = "mactivos_margen", meses = c(201905)),
  list(campo = "mpasivos_margen", meses = c(201905)),
  list(campo = "ccomisiones_otras", meses = c(201905)),
  list(campo = "mcomisiones_otras", meses = c(201905)),
  list(campo = "ccajeros_propios_descuentos", meses = c(202002, 202009, 202010, 202102)),
  list(campo = "mcajeros_propios_descuentos", meses = c(202002, 202009, 202010, 202102)),
  list(campo = "ctarjeta_visa_descuentos", meses = c(202002, 202009, 202010, 202102)),
  list(campo = "mtarjeta_visa_descuentos", meses = c(202002, 202009, 202010, 202102)),
  list(campo = "ctarjeta_master_descuentos", meses = c(202002, 202009, 202010, 202102)),
  list(campo = "mtarjeta_master_descuentos", meses = c(202002, 202009, 202010, 202102)),
  list(campo = "ccajas_depositos", meses = c(202105))
)

# %%
for (item in atributos_y_meses) {
  campo <- item$campo
  meses <- item$meses
  
  cat("Corrigiendo", campo, "en meses", paste(meses, collapse = ", "), "...\n")
  dataset <- corregir_interpolar(dataset, campo, meses)
}
# Out:
# Corrigiendo ctarjeta_visa_debitos_automaticos en meses 201904 ...
# Corrigiendo mttarjeta_visa_debitos_automaticos en meses 201904 ...
# Corrigiendo mrentabilidad en meses 201905 ...
# Corrigiendo mrentabilidad_annual en meses 201905 ...
# Corrigiendo mcomisiones en meses 201905 ...
# Corrigiendo mactivos_margen en meses 201905 ...
# Corrigiendo mpasivos_margen en meses 201905 ...
# Corrigiendo ccomisiones_otras en meses 201905 ...
# Corrigiendo mcomisiones_otras en meses 201905 ...
# Corrigiendo ccajeros_propios_descuentos en meses 202002, 202009, 202010, 202102 ...
# Corrigiendo mcajeros_propios_descuentos en meses 202002, 202009, 202010, 202102 ...
# Corrigiendo ctarjeta_visa_descuentos en meses 202002, 202009, 202010, 202102 ...
# Corrigiendo mtarjeta_visa_descuentos en meses 202002, 202009, 202010, 202102 ...
# Corrigiendo ctarjeta_master_descuentos en meses 202002, 202009, 202010, 202102 ...
# Corrigiendo mtarjeta_master_descuentos en meses 202002, 202009, 202010, 202102 ...
# Corrigiendo ccajas_depositos en meses 202105 ...

# %% [markdown]
# ### Data Drifting

# %% [markdown]
# Deflacto montos con IPC utilizando 202106 como base. Utilizo como fuente: https://datos.gob.ar/series/api/series/?ids=148.3_INIVELNAL_DICI_M_26&utm_source=chatgpt.com&representation_mode=value&start_date=2020-01-01&end_date=2021-09-01&chartType=column

# %%
drift_inf <- function(dataset, campos_monetarios, ind) {
  
  setDT(dataset)
  setDT(ind)
  
  # Merge para agregar coef por foto_mes
  dataset[ind, coef := i.coef, on = "foto_mes"]
  
  # Deflactar: monto_real = monto_nominal * coef
  for (campo in campos_monetarios) {
    dataset[, (campo) := get(campo) * coef]
  }
  
  # Quitar coef columna auxiliar
  dataset[, coef := NULL]
  
  invisible(dataset) 
}

# %%
ind <- data.table(
  foto_mes = c(
    201901, 201902, 201903, 201904, 201905, 201906,
    201907, 201908, 201909, 201910, 201911, 201912,
    202001, 202002, 202003, 202004, 202005, 202006,
    202007, 202008, 202009, 202010, 202011, 202012,
    202101, 202102, 202103, 202104, 202105, 202106,
    202107, 202108, 202109
  ),
  
  coef = c(
    2.550498, 2.457942, 2.348029, 2.270849, 2.202487, 2.144187,
    2.098139, 2.018280, 1.906113, 1.845309, 1.770002, 1.706181,
    1.668564, 1.630094, 1.582720, 1.549057, 1.535367, 1.502003,
    1.473492, 1.434759, 1.395188, 1.344603, 1.303434, 1.253239,
    1.204453, 1.162891, 1.109505, 1.066020, 1.031724, 1.000000,
    0.970889, 0.947511, 0.915043
  )
)

# %%
# Campos de montos
campos_monetarios <- names(dataset)[
  startsWith(names(dataset), "m") |
  startsWith(names(dataset), "Visa_m") |
  startsWith(names(dataset), "Master_m") |
  startsWith(names(dataset), "vm_m")
]

# Aplico
drift_inf(dataset, campos_monetarios, ind)

# %% [markdown]
# ### Feature Engineering Intra-Mes

# %% [markdown]
# Crear variables nuevas a partir de las existentes dentro del mismo registro, **sin** ir a buscar información histórica.

# %%
library(DBI)
library(duckdb)

fe_intrames <- function(df_fe) {
  # Aseguramos data.table / data.frame
  df_fe <- as.data.table(df_fe)
  
  # Conexión DuckDB en memoria
  con <- dbConnect(duckdb(), dbdir = ":memory:")
  on.exit(dbDisconnect(con, shutdown = TRUE))
  
  # Registrar el data.frame como tabla en DuckDB
  duckdb_register(con, "competencia_02", df_fe)
  
  # Macros
  dbExecute(con, "
    CREATE OR REPLACE MACRO suma_sin_null(a, b) AS ifnull(a, 0) + ifnull(b, 0);
  ")
  
  dbExecute(con, "
    CREATE OR REPLACE MACRO div(a, b) AS 
      CASE 
        WHEN ifnull(b, 0) = 0 THEN NULL 
        ELSE ifnull(a, 0) / ifnull(b, 1) 
      END;
  ")
  
  # Query principal 
  query <- "
    WITH sumas AS (
        SELECT
            *
          , suma_sin_null(mtarjeta_visa_consumo, mtarjeta_master_consumo) AS tc_consumo_total
          , suma_sin_null(Master_mfinanciacion_limite, Visa_mfinanciacion_limite) AS tc_financiacionlimite_total
          , suma_sin_null(Master_msaldopesos, Visa_msaldopesos) AS tc_saldopesos_total
          , suma_sin_null(Master_msaldodolares, Visa_msaldodolares) AS tc_saldodolares_total
          , suma_sin_null(Master_mconsumospesos, Visa_mconsumospesos) AS tc_consumopesos_total
          , suma_sin_null(Master_mconsumosdolares, Visa_mconsumosdolares) AS tc_consumodolares_total
          , suma_sin_null(Master_mlimitecompra, Visa_mlimitecompra) AS tc_limitecompra_total
          , suma_sin_null(Master_madelantopesos, Visa_madelantopesos) AS tc_adelantopesos_total
          , suma_sin_null(Master_madelantodolares, Visa_madelantodolares) AS tc_adelantodolares_total
          , suma_sin_null(tc_adelantopesos_total, tc_adelantodolares_total) AS tc_adelanto_total
          , suma_sin_null(Master_mpagado, Visa_mpagado) AS tc_pagado_total
          , suma_sin_null(Master_mpagospesos, Visa_mpagospesos) AS tc_pagadopesos_total
          , suma_sin_null(Master_mpagosdolares, Visa_mpagosdolares) AS tc_pagadodolares_total
          , suma_sin_null(Master_msaldototal, Visa_msaldototal) AS tc_saldototal_total
          , suma_sin_null(Master_mconsumototal, Visa_mconsumototal) AS tc_consumototal_total
          , suma_sin_null(Master_cconsumos, Visa_cconsumos) AS tc_cconsumos_total
          , suma_sin_null(Master_delinquency, Visa_delinquency) AS tc_morosidad_total
          , suma_sin_null(mplazo_fijo_dolares, mplazo_fijo_pesos) AS m_plazofijo_total
          , suma_sin_null(minversion1_dolares, minversion1_pesos) AS m_inversion1_total
          , suma_sin_null(mpayroll, mpayroll2) AS m_payroll_total
          , suma_sin_null(cpayroll_trx, cpayroll2_trx) AS c_payroll_total
          , suma_sin_null(
                suma_sin_null(suma_sin_null(cseguro_vida, cseguro_auto), cseguro_vivienda),
                cseguro_accidentes_personales
            ) AS c_seguros_total
        FROM competencia_02
    )
    SELECT
        sumas.*
      , div(m_plazofijo_total, cplazo_fijo) AS m_promedio_plazofijo_total
      , div(m_inversion1_total, cinversion1) AS m_promedio_inversion_total
      , div(mcaja_ahorro, ccaja_ahorro) AS m_promedio_caja_ahorro
      , div(mtarjeta_visa_consumo, ctarjeta_visa_transacciones) AS m_promedio_tarjeta_visa_consumo_por_transaccion
      , div(mtarjeta_master_consumo, ctarjeta_master_transacciones) AS m_promedio_tarjeta_master_consumo_por_transaccion
      , div(mprestamos_prendarios, cprestamos_prendarios) AS m_promedio_prestamos_prendarios
      , div(mprestamos_hipotecarios, cprestamos_hipotecarios) AS m_promedio_prestamos_hipotecarios
      , div(minversion2, cinversion2) AS m_promedio_inversion2
      , div(mpagodeservicios, cpagodeservicios) AS m_promedio_pagodeservicios
      , div(mpagomiscuentas, cpagomiscuentas) AS m_promedio_pagomiscuentas
      , div(mcajeros_propios_descuentos, ccajeros_propios_descuentos) AS m_promedio_cajeros_propios_descuentos
      , div(mtarjeta_visa_descuentos, ctarjeta_visa_descuentos) AS m_promedio_tarjeta_visa_descuentos
      , div(mtarjeta_master_descuentos, ctarjeta_master_descuentos) AS m_promedio_tarjeta_master_descuentos
      , div(mcomisiones_mantenimiento, ccomisiones_mantenimiento) AS m_promedio_comisiones_mantenimiento
      , div(mcomisiones_otras, ccomisiones_otras) AS m_promedio_comisiones_otras
      , div(mforex_buy, cforex_buy) AS m_promedio_forex_buy
      , div(mforex_sell, cforex_sell) AS m_promedio_forex_sell
      , div(mtransferencias_recibidas, ctransferencias_recibidas) AS m_promedio_transferencias_recibidas
      , div(mtransferencias_emitidas, ctransferencias_emitidas) AS m_promedio_transferencias_emitidas
      , div(mextraccion_autoservicio, cextraccion_autoservicio) AS m_promedio_extraccion_autoservicio
      , div(mcheques_depositados, ccheques_depositados) AS m_promedio_cheques_depositados
      , div(mcheques_emitidos, ccheques_emitidos) AS m_promedio_cheques_emitidos
      , div(mcheques_depositados_rechazados, ccheques_depositados_rechazados) AS m_promedio_cheques_depositados_rechazados
      , div(mcheques_emitidos_rechazados, ccheques_emitidos_rechazados) AS m_promedio_cheques_emitidos_rechazados
      , div(matm, catm_trx) AS m_promedio_atm
      , div(matm_other, catm_trx_other) AS m_promedio_atm_other
      , div(Master_msaldototal, Master_mfinanciacion_limite) AS proporcion_financiacion_master_cubierto
      , div(Master_msaldototal, Master_mlimitecompra) AS proporcion_limite_master_cubierto
      , div(Visa_msaldototal, Visa_mfinanciacion_limite) AS proporcion_financiacion_visa_cubierto
      , div(Visa_msaldototal, Visa_mlimitecompra) AS proporcion_limite_visa_cubierto
      , div(tc_saldototal_total, tc_financiacionlimite_total) AS proporcion_financiacion_total_cubierto
      , div(tc_saldototal_total, tc_limitecompra_total) AS proporcion_limite_total_cubierto
      , div(tc_saldopesos_total, tc_saldototal_total) AS tc_proporcion_saldo_pesos
      , div(tc_saldodolares_total, tc_saldototal_total) AS tc_proporcion_saldo_dolares
      , div(tc_consumopesos_total, tc_consumototal_total) AS tc_proporcion_consumo_pesos
      , div(tc_consumodolares_total, tc_consumototal_total) AS tc_proporcion_consumo_dolares
      , div(tc_consumototal_total, tc_limitecompra_total) AS tc_proporcion_consumo_total_limite_total_cubierto
      , div(tc_pagadopesos_total, tc_pagado_total) AS tc_proporcion_pago_pesos
      , div(tc_pagadodolares_total, tc_pagado_total) AS tc_proporcion_pago_dolares
      , div(tc_adelantopesos_total, tc_adelanto_total) AS tc_proporcion_adelanto_pesos
      , div(tc_adelantodolares_total, tc_adelanto_total) AS tc_proporcion_adelanto_dolares
    FROM sumas
  "
  
  res <- dbGetQuery(con, query)
  as.data.table(res)
}

# %%
# Aplico
dataset <- fe_intrames(dataset)

# %%
# el mes 1,2, ..12 , podria servir para detectar estacionalidad
dataset[, kmes := foto_mes %% 100]

# creo un ctr_quarter que tenga en cuenta cuando
# los clientes hace 3 menos meses que estan
# ya que seria injusto considerar las transacciones medidas en menor tiempo
dataset[, ctrx_quarter_normalizado := as.numeric(ctrx_quarter) ]
dataset[cliente_antiguedad == 1, ctrx_quarter_normalizado := ctrx_quarter * 5.0]
dataset[cliente_antiguedad == 2, ctrx_quarter_normalizado := ctrx_quarter * 2.0]
dataset[cliente_antiguedad == 3, ctrx_quarter_normalizado := ctrx_quarter * 1.2]

# variable extraida de una tesis de maestria de Irlanda, se perdió el link
dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

Sys.time()
# Out:
# [1] "2025-12-03 23:27:00 UTC"

# %% [markdown]
# ### Feature Engineering Historico

# %%
if( !require("Rcpp")) install.packages("Rcpp", repos = "http://cran.us.r-project.org")
require("Rcpp")
# Out:
# Loading required package: Rcpp

# %%
# se calculan para los 6 meses previos el minimo, maximo y
#  tendencia calculada con cuadrados minimos
# la formula de calculo de la tendencia puede verse en
#  https://stats.libretexts.org/Bookshelves/Introductory_Statistics/Book%3A_Introductory_Statistics_(Shafer_and_Zhang)/10%3A_Correlation_and_Regression/10.04%3A_The_Least_Squares_Regression_Line
# para la maxíma velocidad esta funcion esta escrita en lenguaje C,
# y no en la porqueria de R o Python

cppFunction("NumericVector fhistC(NumericVector pcolumna, IntegerVector pdesde )
{
  /* Aqui se cargan los valores para la regresion */
  double  x[100] ;
  double  y[100] ;

  int n = pcolumna.size();
  NumericVector out( 5*n );

  for(int i = 0; i < n; i++)
  {
    //lag
    if( pdesde[i]-1 < i )  out[ i + 4*n ]  =  pcolumna[i-1] ;
    else                   out[ i + 4*n ]  =  NA_REAL ;


    int  libre    = 0 ;
    int  xvalor   = 1 ;

    for( int j= pdesde[i]-1;  j<=i; j++ )
    {
       double a = pcolumna[j] ;

       if( !R_IsNA( a ) )
       {
          y[ libre ]= a ;
          x[ libre ]= xvalor ;
          libre++ ;
       }

       xvalor++ ;
    }

    /* Si hay al menos dos valores */
    if( libre > 1 )
    {
      double  xsum  = x[0] ;
      double  ysum  = y[0] ;
      double  xysum = xsum * ysum ;
      double  xxsum = xsum * xsum ;
      double  vmin  = y[0] ;
      double  vmax  = y[0] ;

      for( int h=1; h<libre; h++)
      {
        xsum  += x[h] ;
        ysum  += y[h] ;
        xysum += x[h]*y[h] ;
        xxsum += x[h]*x[h] ;

        if( y[h] < vmin )  vmin = y[h] ;
        if( y[h] > vmax )  vmax = y[h] ;
      }

      out[ i ]  =  (libre*xysum - xsum*ysum)/(libre*xxsum -xsum*xsum) ;
      out[ i + n ]    =  vmin ;
      out[ i + 2*n ]  =  vmax ;
      out[ i + 3*n ]  =  ysum / libre ;
    }
    else
    {
      out[ i       ]  =  NA_REAL ;
      out[ i + n   ]  =  NA_REAL ;
      out[ i + 2*n ]  =  NA_REAL ;
      out[ i + 3*n ]  =  NA_REAL ;
    }
  }

  return  out;
}")

# %%
# calcula la tendencia de las variables cols de los ultimos 6 meses
# la tendencia es la pendiente de la recta que ajusta por cuadrados minimos
# La funcionalidad de ratioavg es autoria de  Daiana Sparta,  UAustral  2021

TendenciaYmuchomas <- function(
    dataset, cols, ventana = 6, tendencia = TRUE,
    minimo = TRUE, maximo = TRUE, promedio = TRUE,
    ratioavg = FALSE, ratiomax = FALSE) {
  gc(verbose= FALSE)
  # Esta es la cantidad de meses que utilizo para la historia
  ventana_regresion <- ventana

  last <- nrow(dataset)

  # creo el vector_desde que indica cada ventana
  # de esta forma se acelera el procesamiento ya que lo hago una sola vez
  vector_ids <- dataset[ , numero_de_cliente ]

  vector_desde <- seq(
    -ventana_regresion + 2,
    nrow(dataset) - ventana_regresion + 1
  )

  vector_desde[1:ventana_regresion] <- 1

  for (i in 2:last) {
    if (vector_ids[i - 1] != vector_ids[i]) {
      vector_desde[i] <- i
    }
  }
  for (i in 2:last) {
    if (vector_desde[i] < vector_desde[i - 1]) {
      vector_desde[i] <- vector_desde[i - 1]
    }
  }

  for (campo in cols) {
    nueva_col <- fhistC(dataset[, get(campo)], vector_desde)

    if (tendencia) {
      dataset[, paste0(campo, "_tend", ventana) :=
        nueva_col[(0 * last + 1):(1 * last)]]
    }

    if (minimo) {
      dataset[, paste0(campo, "_min", ventana) :=
        nueva_col[(1 * last + 1):(2 * last)]]
    }

    if (maximo) {
      dataset[, paste0(campo, "_max", ventana) :=
        nueva_col[(2 * last + 1):(3 * last)]]
    }

    if (promedio) {
      dataset[, paste0(campo, "_avg", ventana) :=
        nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratioavg) {
      dataset[, paste0(campo, "_ratioavg", ventana) :=
        get(campo) / nueva_col[(3 * last + 1):(4 * last)]]
    }

    if (ratiomax) {
      dataset[, paste0(campo, "_ratiomax", ventana) :=
        get(campo) / nueva_col[(2 * last + 1):(3 * last)]]
    }
  }
}

# %%
# Feature Engineering Historico
# Creacion de LAGs
setorder(dataset, numero_de_cliente, foto_mes)

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
  colnames(dataset),
  c("numero_de_cliente", "foto_mes", "clase_ternaria")
))

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
  paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# lags de orden 2
dataset[,
  paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
  by= numero_de_cliente,
  .SDcols= cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
  dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
  dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

Sys.time()
# Out:
# [1] "2025-12-03 23:29:09 UTC"

# %%
# parametros de Feature Engineering Historico de Tendencias
PARAM$FE_hist$Tendencias$run <- TRUE
PARAM$FE_hist$Tendencias$ventana <- 6
PARAM$FE_hist$Tendencias$tendencia <- TRUE
PARAM$FE_hist$Tendencias$minimo <- FALSE
PARAM$FE_hist$Tendencias$maximo <- FALSE
PARAM$FE_hist$Tendencias$promedio <- FALSE
PARAM$FE_hist$Tendencias$ratioavg <- FALSE
PARAM$FE_hist$Tendencias$ratiomax <- FALSE

# %%
# aqui se agregan las tendencias de los ultimos 6 meses

cols_lagueables <- intersect(cols_lagueables, colnames(dataset))
setorder(dataset, numero_de_cliente, foto_mes)

if( PARAM$FE_hist$Tendencias$run) {
    TendenciaYmuchomas(dataset,
    cols = cols_lagueables,
    ventana = PARAM$FE_hist$Tendencias$ventana, # 6 meses de historia
    tendencia = PARAM$FE_hist$Tendencias$tendencia,
    minimo = PARAM$FE_hist$Tendencias$minimo,
    maximo = PARAM$FE_hist$Tendencias$maximo,
    promedio = PARAM$FE_hist$Tendencias$promedio,
    ratioavg = PARAM$FE_hist$Tendencias$ratioavg,
    ratiomax = PARAM$FE_hist$Tendencias$ratiomax
  )
}

ncol(dataset)
Sys.time()
# Out:
# [1] 1240
# [1] "2025-12-03 23:30:24 UTC"

# %%
ncol(dataset)
nrow(dataset)
colnames(dataset)
# Out:
# [1] 1240
# [1] 4883051
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "active_quarter"
#    [4] "cliente_vip"
#    [5] "internet"
#    [6] "cliente_edad"
#    [7] "cliente_antiguedad"
#    [8] "mrentabilidad"
#    [9] "mrentabilidad_annual"
#   [10] "mcomisiones"
#   [11] "mactivos_margen"
#   [12] "mpasivos_margen"
#   [13] "cproductos"
#   [14] "tcuentas"
#   [15] "ccuenta_corriente"
#   [16] "mcuenta_corriente_adicional"
#   [17] "mcuenta_corriente"
#   [18] "ccaja_ahorro"
#   [19] "mcaja_ahorro"
#   [20] "mcaja_ahorro_adicional"
#   [21] "mcaja_ahorro_dolares"
#   [22] "cdescubierto_preacordado"
#   [23] "mcuentas_saldo"
#   [24] "ctarjeta_debito"
#   [25] "ctarjeta_debito_transacciones"
#   [26] "mautoservicio"
#   [27] "ctarjeta_visa"
#   [28] "ctarjeta_visa_transacciones"
#   [29] "mtarjeta_visa_consumo"
#   [30] "ctarjeta_master"
#   [31] "ctarjeta_master_transacciones"
#   [32] "mtarjeta_master_consumo"
#   [33] "cprestamos_prendarios"
#   [34] "mprestamos_prendarios"
#   [35] "cprestamos_hipotecarios"
#   [36] "mprestamos_hipotecarios"
#   [37] "cplazo_fijo"
#   [38] "mplazo_fijo_dolares"
#   [39] "mplazo_fijo_pesos"
#   [40] "cinversion1"
#   [41] "minversion1_pesos"
#   [42] "minversion1_dolares"
#   [43] "cinversion2"
#   [44] "minversion2"
#   [45] "cseguro_vida"
#   [46] "cseguro_auto"
#   [47] "cseguro_vivienda"
#   [48] "cseguro_accidentes_personales"
#   [49] "ccaja_seguridad"
#   [50] "cpayroll_trx"
#   [51] "mpayroll"
#   [52] "mpayroll2"
#   [53] "cpayroll2_trx"
#   [54] "ccuenta_debitos_automaticos"
#   [55] "mcuenta_debitos_automaticos"
#   [56] "ctarjeta_visa_debitos_automaticos"
#   [57] "mttarjeta_visa_debitos_automaticos"
#   [58] "ctarjeta_master_debitos_automaticos"
#   [59] "mttarjeta_master_debitos_automaticos"
#   [60] "cpagodeservicios"
#   [61] "mpagodeservicios"
#   [62] "cpagomiscuentas"
#   [63] "mpagomiscuentas"
#   [64] "ccajeros_propios_descuentos"
#   [65] "mcajeros_propios_descuentos"
#   [66] "ctarjeta_visa_descuentos"
#   [67] "mtarjeta_visa_descuentos"
#   [68] "ctarjeta_master_descuentos"
#   [69] "mtarjeta_master_descuentos"
#   [70] "ccomisiones_mantenimiento"
#   [71] "mcomisiones_mantenimiento"
#   [72] "ccomisiones_otras"
#   [73] "mcomisiones_otras"
#   [74] "cforex"
#   [75] "cforex_buy"
#   [76] "mforex_buy"
#   [77] "cforex_sell"
#   [78] "mforex_sell"
#   [79] "ctransferencias_recibidas"
#   [80] "mtransferencias_recibidas"
#   [81] "ctransferencias_emitidas"
#   [82] "mtransferencias_emitidas"
#   [83] "cextraccion_autoservicio"
#   [84] "mextraccion_autoservicio"
#   [85] "ccheques_depositados"
#   [86] "mcheques_depositados"
#   [87] "ccheques_emitidos"
#   [88] "mcheques_emitidos"
#   [89] "ccheques_depositados_rechazados"
#   [90] "mcheques_depositados_rechazados"
#   [91] "ccheques_emitidos_rechazados"
#   [92] "mcheques_emitidos_rechazados"
#   [93] "tcallcenter"
#   [94] "ccallcenter_transacciones"
#   [95] "thomebanking"
#   [96] "chomebanking_transacciones"
#   [97] "ccajas_transacciones"
#   [98] "ccajas_consultas"
#   [99] "ccajas_depositos"
#  [100] "ccajas_extracciones"
#  [101] "ccajas_otras"
#  [102] "catm_trx"
#  [103] "matm"
#  [104] "catm_trx_other"
#  [105] "matm_other"
#  [106] "ctrx_quarter"
#  [107] "tmobile_app"
#  [108] "cmobile_app_trx"
#  [109] "Master_delinquency"
#  [110] "Master_status"
#  [111] "Master_mfinanciacion_limite"
#  [112] "Master_Fvencimiento"
#  [113] "Master_Finiciomora"
#  [114] "Master_msaldototal"
#  [115] "Master_msaldopesos"
#  [116] "Master_msaldodolares"
#  [117] "Master_mconsumospesos"
#  [118] "Master_mconsumosdolares"
#  [119] "Master_mlimitecompra"
#  [120] "Master_madelantopesos"
#  [121] "Master_madelantodolares"
#  [122] "Master_fultimo_cierre"
#  [123] "Master_mpagado"
#  [124] "Master_mpagospesos"
#  [125] "Master_mpagosdolares"
#  [126] "Master_fechaalta"
#  [127] "Master_mconsumototal"
#  [128] "Master_cconsumos"
#  [129] "Master_cadelantosefectivo"
#  [130] "Master_mpagominimo"
#  [131] "Visa_delinquency"
#  [132] "Visa_status"
#  [133] "Visa_mfinanciacion_limite"
#  [134] "Visa_Fvencimiento"
#  [135] "Visa_Finiciomora"
#  [136] "Visa_msaldototal"
#  [137] "Visa_msaldopesos"
#  [138] "Visa_msaldodolares"
#  [139] "Visa_mconsumospesos"
#  [140] "Visa_mconsumosdolares"
#  [141] "Visa_mlimitecompra"
#  [142] "Visa_madelantopesos"
#  [143] "Visa_madelantodolares"
#  [144] "Visa_fultimo_cierre"
#  [145] "Visa_mpagado"
#  [146] "Visa_mpagospesos"
#  [147] "Visa_mpagosdolares"
#  [148] "Visa_fechaalta"
#  [149] "Visa_mconsumototal"
#  [150] "Visa_cconsumos"
#  [151] "Visa_cadelantosefectivo"
#  [152] "Visa_mpagominimo"
#  [153] "clase_ternaria"
#  [154] "tc_consumo_total"
#  [155] "tc_financiacionlimite_total"
#  [156] "tc_saldopesos_total"
#  [157] "tc_saldodolares_total"
#  [158] "tc_consumopesos_total"
#  [159] "tc_consumodolares_total"
#  [160] "tc_limitecompra_total"
#  [161] "tc_adelantopesos_total"
#  [162] "tc_adelantodolares_total"
#  [163] "tc_adelanto_total"
#  [164] "tc_pagado_total"
#  [165] "tc_pagadopesos_total"
#  [166] "tc_pagadodolares_total"
#  [167] "tc_saldototal_total"
#  [168] "tc_consumototal_total"
#  [169] "tc_cconsumos_total"
#  [170] "tc_morosidad_total"
#  [171] "m_plazofijo_total"
#  [172] "m_inversion1_total"
#  [173] "m_payroll_total"
#  [174] "c_payroll_total"
#  [175] "c_seguros_total"
#  [176] "m_promedio_plazofijo_total"
#  [177] "m_promedio_inversion_total"
#  [178] "m_promedio_caja_ahorro"
#  [179] "m_promedio_tarjeta_visa_consumo_por_transaccion"
#  [180] "m_promedio_tarjeta_master_consumo_por_transaccion"
#  [181] "m_promedio_prestamos_prendarios"
#  [182] "m_promedio_prestamos_hipotecarios"
#  [183] "m_promedio_inversion2"
#  [184] "m_promedio_pagodeservicios"
#  [185] "m_promedio_pagomiscuentas"
#  [186] "m_promedio_cajeros_propios_descuentos"
#  [187] "m_promedio_tarjeta_visa_descuentos"
#  [188] "m_promedio_tarjeta_master_descuentos"
#  [189] "m_promedio_comisiones_mantenimiento"
#  [190] "m_promedio_comisiones_otras"
#  [191] "m_promedio_forex_buy"
#  [192] "m_promedio_forex_sell"
#  [193] "m_promedio_transferencias_recibidas"
#  [194] "m_promedio_transferencias_emitidas"
#  [195] "m_promedio_extraccion_autoservicio"
#  [196] "m_promedio_cheques_depositados"
#  [197] "m_promedio_cheques_emitidos"
#  [198] "m_promedio_cheques_depositados_rechazados"
#  [199] "m_promedio_cheques_emitidos_rechazados"
#  [200] "m_promedio_atm"
#  [201] "m_promedio_atm_other"
#  [202] "proporcion_financiacion_master_cubierto"
#  [203] "proporcion_limite_master_cubierto"
#  [204] "proporcion_financiacion_visa_cubierto"
#  [205] "proporcion_limite_visa_cubierto"
#  [206] "proporcion_financiacion_total_cubierto"
#  [207] "proporcion_limite_total_cubierto"
#  [208] "tc_proporcion_saldo_pesos"
#  [209] "tc_proporcion_saldo_dolares"
#  [210] "tc_proporcion_consumo_pesos"
#  [211] "tc_proporcion_consumo_dolares"
#  [212] "tc_proporcion_consumo_total_limite_total_cubierto"
#  [213] "tc_proporcion_pago_pesos"
#  [214] "tc_proporcion_pago_dolares"
#  [215] "tc_proporcion_adelanto_pesos"
#  [216] "tc_proporcion_adelanto_dolares"
#  [217] "kmes"
#  [218] "ctrx_quarter_normalizado"
#  [219] "mpayroll_sobre_edad"
#  [220] "active_quarter_lag1"
#  [221] "cliente_vip_lag1"
#  [222] "internet_lag1"
#  [223] "cliente_edad_lag1"
#  [224] "cliente_antiguedad_lag1"
#  [225] "mrentabilidad_lag1"
#  [226] "mrentabilidad_annual_lag1"
#  [227] "mcomisiones_lag1"
#  [228] "mactivos_margen_lag1"
#  [229] "mpasivos_margen_lag1"
#  [230] "cproductos_lag1"
#  [231] "tcuentas_lag1"
#  [232] "ccuenta_corriente_lag1"
#  [233] "mcuenta_corriente_adicional_lag1"
#  [234] "mcuenta_corriente_lag1"
#  [235] "ccaja_ahorro_lag1"
#  [236] "mcaja_ahorro_lag1"
#  [237] "mcaja_ahorro_adicional_lag1"
#  [238] "mcaja_ahorro_dolares_lag1"
#  [239] "cdescubierto_preacordado_lag1"
#  [240] "mcuentas_saldo_lag1"
#  [241] "ctarjeta_debito_lag1"
#  [242] "ctarjeta_debito_transacciones_lag1"
#  [243] "mautoservicio_lag1"
#  [244] "ctarjeta_visa_lag1"
#  [245] "ctarjeta_visa_transacciones_lag1"
#  [246] "mtarjeta_visa_consumo_lag1"
#  [247] "ctarjeta_master_lag1"
#  [248] "ctarjeta_master_transacciones_lag1"
#  [249] "mtarjeta_master_consumo_lag1"
#  [250] "cprestamos_prendarios_lag1"
#  [251] "mprestamos_prendarios_lag1"
#  [252] "cprestamos_hipotecarios_lag1"
#  [253] "mprestamos_hipotecarios_lag1"
#  [254] "cplazo_fijo_lag1"
#  [255] "mplazo_fijo_dolares_lag1"
#  [256] "mplazo_fijo_pesos_lag1"
#  [257] "cinversion1_lag1"
#  [258] "minversion1_pesos_lag1"
#  [259] "minversion1_dolares_lag1"
#  [260] "cinversion2_lag1"
#  [261] "minversion2_lag1"
#  [262] "cseguro_vida_lag1"
#  [263] "cseguro_auto_lag1"
#  [264] "cseguro_vivienda_lag1"
#  [265] "cseguro_accidentes_personales_lag1"
#  [266] "ccaja_seguridad_lag1"
#  [267] "cpayroll_trx_lag1"
#  [268] "mpayroll_lag1"
#  [269] "mpayroll2_lag1"
#  [270] "cpayroll2_trx_lag1"
#  [271] "ccuenta_debitos_automaticos_lag1"
#  [272] "mcuenta_debitos_automaticos_lag1"
#  [273] "ctarjeta_visa_debitos_automaticos_lag1"
#  [274] "mttarjeta_visa_debitos_automaticos_lag1"
#  [275] "ctarjeta_master_debitos_automaticos_lag1"
#  [276] "mttarjeta_master_debitos_automaticos_lag1"
#  [277] "cpagodeservicios_lag1"
#  [278] "mpagodeservicios_lag1"
#  [279] "cpagomiscuentas_lag1"
#  [280] "mpagomiscuentas_lag1"
#  [281] "ccajeros_propios_descuentos_lag1"
#  [282] "mcajeros_propios_descuentos_lag1"
#  [283] "ctarjeta_visa_descuentos_lag1"
#  [284] "mtarjeta_visa_descuentos_lag1"
#  [285] "ctarjeta_master_descuentos_lag1"
#  [286] "mtarjeta_master_descuentos_lag1"
#  [287] "ccomisiones_mantenimiento_lag1"
#  [288] "mcomisiones_mantenimiento_lag1"
#  [289] "ccomisiones_otras_lag1"
#  [290] "mcomisiones_otras_lag1"
#  [291] "cforex_lag1"
#  [292] "cforex_buy_lag1"
#  [293] "mforex_buy_lag1"
#  [294] "cforex_sell_lag1"
#  [295] "mforex_sell_lag1"
#  [296] "ctransferencias_recibidas_lag1"
#  [297] "mtransferencias_recibidas_lag1"
#  [298] "ctransferencias_emitidas_lag1"
#  [299] "mtransferencias_emitidas_lag1"
#  [300] "cextraccion_autoservicio_lag1"
#  [301] "mextraccion_autoservicio_lag1"
#  [302] "ccheques_depositados_lag1"
#  [303] "mcheques_depositados_lag1"
#  [304] "ccheques_emitidos_lag1"
#  [305] "mcheques_emitidos_lag1"
#  [306] "ccheques_depositados_rechazados_lag1"
#  [307] "mcheques_depositados_rechazados_lag1"
#  [308] "ccheques_emitidos_rechazados_lag1"
#  [309] "mcheques_emitidos_rechazados_lag1"
#  [310] "tcallcenter_lag1"
#  [311] "ccallcenter_transacciones_lag1"
#  [312] "thomebanking_lag1"
#  [313] "chomebanking_transacciones_lag1"
#  [314] "ccajas_transacciones_lag1"
#  [315] "ccajas_consultas_lag1"
#  [316] "ccajas_depositos_lag1"
#  [317] "ccajas_extracciones_lag1"
#  [318] "ccajas_otras_lag1"
#  [319] "catm_trx_lag1"
#  [320] "matm_lag1"
#  [321] "catm_trx_other_lag1"
#  [322] "matm_other_lag1"
#  [323] "ctrx_quarter_lag1"
#  [324] "tmobile_app_lag1"
#  [325] "cmobile_app_trx_lag1"
#  [326] "Master_delinquency_lag1"
#  [327] "Master_status_lag1"
#  [328] "Master_mfinanciacion_limite_lag1"
#  [329] "Master_Fvencimiento_lag1"
#  [330] "Master_Finiciomora_lag1"
#  [331] "Master_msaldototal_lag1"
#  [332] "Master_msaldopesos_lag1"
#  [333] "Master_msaldodolares_lag1"
#  [334] "Master_mconsumospesos_lag1"
#  [335] "Master_mconsumosdolares_lag1"
#  [336] "Master_mlimitecompra_lag1"
#  [337] "Master_madelantopesos_lag1"
#  [338] "Master_madelantodolares_lag1"
#  [339] "Master_fultimo_cierre_lag1"
#  [340] "Master_mpagado_lag1"
#  [341] "Master_mpagospesos_lag1"
#  [342] "Master_mpagosdolares_lag1"
#  [343] "Master_fechaalta_lag1"
#  [344] "Master_mconsumototal_lag1"
#  [345] "Master_cconsumos_lag1"
#  [346] "Master_cadelantosefectivo_lag1"
#  [347] "Master_mpagominimo_lag1"
#  [348] "Visa_delinquency_lag1"
#  [349] "Visa_status_lag1"
#  [350] "Visa_mfinanciacion_limite_lag1"
#  [351] "Visa_Fvencimiento_lag1"
#  [352] "Visa_Finiciomora_lag1"
#  [353] "Visa_msaldototal_lag1"
#  [354] "Visa_msaldopesos_lag1"
#  [355] "Visa_msaldodolares_lag1"
#  [356] "Visa_mconsumospesos_lag1"
#  [357] "Visa_mconsumosdolares_lag1"
#  [358] "Visa_mlimitecompra_lag1"
#  [359] "Visa_madelantopesos_lag1"
#  [360] "Visa_madelantodolares_lag1"
#  [361] "Visa_fultimo_cierre_lag1"
#  [362] "Visa_mpagado_lag1"
#  [363] "Visa_mpagospesos_lag1"
#  [364] "Visa_mpagosdolares_lag1"
#  [365] "Visa_fechaalta_lag1"
#  [366] "Visa_mconsumototal_lag1"
#  [367] "Visa_cconsumos_lag1"
#  [368] "Visa_cadelantosefectivo_lag1"
#  [369] "Visa_mpagominimo_lag1"
#  [370] "tc_consumo_total_lag1"
#  [371] "tc_financiacionlimite_total_lag1"
#  [372] "tc_saldopesos_total_lag1"
#  [373] "tc_saldodolares_total_lag1"
#  [374] "tc_consumopesos_total_lag1"
#  [375] "tc_consumodolares_total_lag1"
#  [376] "tc_limitecompra_total_lag1"
#  [377] "tc_adelantopesos_total_lag1"
#  [378] "tc_adelantodolares_total_lag1"
#  [379] "tc_adelanto_total_lag1"
#  [380] "tc_pagado_total_lag1"
#  [381] "tc_pagadopesos_total_lag1"
#  [382] "tc_pagadodolares_total_lag1"
#  [383] "tc_saldototal_total_lag1"
#  [384] "tc_consumototal_total_lag1"
#  [385] "tc_cconsumos_total_lag1"
#  [386] "tc_morosidad_total_lag1"
#  [387] "m_plazofijo_total_lag1"
#  [388] "m_inversion1_total_lag1"
#  [389] "m_payroll_total_lag1"
#  [390] "c_payroll_total_lag1"
#  [391] "c_seguros_total_lag1"
#  [392] "m_promedio_plazofijo_total_lag1"
#  [393] "m_promedio_inversion_total_lag1"
#  [394] "m_promedio_caja_ahorro_lag1"
#  [395] "m_promedio_tarjeta_visa_consumo_por_transaccion_lag1"
#  [396] "m_promedio_tarjeta_master_consumo_por_transaccion_lag1"
#  [397] "m_promedio_prestamos_prendarios_lag1"
#  [398] "m_promedio_prestamos_hipotecarios_lag1"
#  [399] "m_promedio_inversion2_lag1"
#  [400] "m_promedio_pagodeservicios_lag1"
#  [401] "m_promedio_pagomiscuentas_lag1"
#  [402] "m_promedio_cajeros_propios_descuentos_lag1"
#  [403] "m_promedio_tarjeta_visa_descuentos_lag1"
#  [404] "m_promedio_tarjeta_master_descuentos_lag1"
#  [405] "m_promedio_comisiones_mantenimiento_lag1"
#  [406] "m_promedio_comisiones_otras_lag1"
#  [407] "m_promedio_forex_buy_lag1"
#  [408] "m_promedio_forex_sell_lag1"
#  [409] "m_promedio_transferencias_recibidas_lag1"
#  [410] "m_promedio_transferencias_emitidas_lag1"
#  [411] "m_promedio_extraccion_autoservicio_lag1"
#  [412] "m_promedio_cheques_depositados_lag1"
#  [413] "m_promedio_cheques_emitidos_lag1"
#  [414] "m_promedio_cheques_depositados_rechazados_lag1"
#  [415] "m_promedio_cheques_emitidos_rechazados_lag1"
#  [416] "m_promedio_atm_lag1"
#  [417] "m_promedio_atm_other_lag1"
#  [418] "proporcion_financiacion_master_cubierto_lag1"
#  [419] "proporcion_limite_master_cubierto_lag1"
#  [420] "proporcion_financiacion_visa_cubierto_lag1"
#  [421] "proporcion_limite_visa_cubierto_lag1"
#  [422] "proporcion_financiacion_total_cubierto_lag1"
#  [423] "proporcion_limite_total_cubierto_lag1"
#  [424] "tc_proporcion_saldo_pesos_lag1"
#  [425] "tc_proporcion_saldo_dolares_lag1"
#  [426] "tc_proporcion_consumo_pesos_lag1"
#  [427] "tc_proporcion_consumo_dolares_lag1"
#  [428] "tc_proporcion_consumo_total_limite_total_cubierto_lag1"
#  [429] "tc_proporcion_pago_pesos_lag1"
#  [430] "tc_proporcion_pago_dolares_lag1"
#  [431] "tc_proporcion_adelanto_pesos_lag1"
#  [432] "tc_proporcion_adelanto_dolares_lag1"
#  [433] "kmes_lag1"
#  [434] "ctrx_quarter_normalizado_lag1"
#  [435] "mpayroll_sobre_edad_lag1"
#  [436] "active_quarter_lag2"
#  [437] "cliente_vip_lag2"
#  [438] "internet_lag2"
#  [439] "cliente_edad_lag2"
#  [440] "cliente_antiguedad_lag2"
#  [441] "mrentabilidad_lag2"
#  [442] "mrentabilidad_annual_lag2"
#  [443] "mcomisiones_lag2"
#  [444] "mactivos_margen_lag2"
#  [445] "mpasivos_margen_lag2"
#  [446] "cproductos_lag2"
#  [447] "tcuentas_lag2"
#  [448] "ccuenta_corriente_lag2"
#  [449] "mcuenta_corriente_adicional_lag2"
#  [450] "mcuenta_corriente_lag2"
#  [451] "ccaja_ahorro_lag2"
#  [452] "mcaja_ahorro_lag2"
#  [453] "mcaja_ahorro_adicional_lag2"
#  [454] "mcaja_ahorro_dolares_lag2"
#  [455] "cdescubierto_preacordado_lag2"
#  [456] "mcuentas_saldo_lag2"
#  [457] "ctarjeta_debito_lag2"
#  [458] "ctarjeta_debito_transacciones_lag2"
#  [459] "mautoservicio_lag2"
#  [460] "ctarjeta_visa_lag2"
#  [461] "ctarjeta_visa_transacciones_lag2"
#  [462] "mtarjeta_visa_consumo_lag2"
#  [463] "ctarjeta_master_lag2"
#  [464] "ctarjeta_master_transacciones_lag2"
#  [465] "mtarjeta_master_consumo_lag2"
#  [466] "cprestamos_prendarios_lag2"
#  [467] "mprestamos_prendarios_lag2"
#  [468] "cprestamos_hipotecarios_lag2"
#  [469] "mprestamos_hipotecarios_lag2"
#  [470] "cplazo_fijo_lag2"
#  [471] "mplazo_fijo_dolares_lag2"
#  [472] "mplazo_fijo_pesos_lag2"
#  [473] "cinversion1_lag2"
#  [474] "minversion1_pesos_lag2"
#  [475] "minversion1_dolares_lag2"
#  [476] "cinversion2_lag2"
#  [477] "minversion2_lag2"
#  [478] "cseguro_vida_lag2"
#  [479] "cseguro_auto_lag2"
#  [480] "cseguro_vivienda_lag2"
#  [481] "cseguro_accidentes_personales_lag2"
#  [482] "ccaja_seguridad_lag2"
#  [483] "cpayroll_trx_lag2"
#  [484] "mpayroll_lag2"
#  [485] "mpayroll2_lag2"
#  [486] "cpayroll2_trx_lag2"
#  [487] "ccuenta_debitos_automaticos_lag2"
#  [488] "mcuenta_debitos_automaticos_lag2"
#  [489] "ctarjeta_visa_debitos_automaticos_lag2"
#  [490] "mttarjeta_visa_debitos_automaticos_lag2"
#  [491] "ctarjeta_master_debitos_automaticos_lag2"
#  [492] "mttarjeta_master_debitos_automaticos_lag2"
#  [493] "cpagodeservicios_lag2"
#  [494] "mpagodeservicios_lag2"
#  [495] "cpagomiscuentas_lag2"
#  [496] "mpagomiscuentas_lag2"
#  [497] "ccajeros_propios_descuentos_lag2"
#  [498] "mcajeros_propios_descuentos_lag2"
#  [499] "ctarjeta_visa_descuentos_lag2"
#  [500] "mtarjeta_visa_descuentos_lag2"
#  [501] "ctarjeta_master_descuentos_lag2"
#  [502] "mtarjeta_master_descuentos_lag2"
#  [503] "ccomisiones_mantenimiento_lag2"
#  [504] "mcomisiones_mantenimiento_lag2"
#  [505] "ccomisiones_otras_lag2"
#  [506] "mcomisiones_otras_lag2"
#  [507] "cforex_lag2"
#  [508] "cforex_buy_lag2"
#  [509] "mforex_buy_lag2"
#  [510] "cforex_sell_lag2"
#  [511] "mforex_sell_lag2"
#  [512] "ctransferencias_recibidas_lag2"
#  [513] "mtransferencias_recibidas_lag2"
#  [514] "ctransferencias_emitidas_lag2"
#  [515] "mtransferencias_emitidas_lag2"
#  [516] "cextraccion_autoservicio_lag2"
#  [517] "mextraccion_autoservicio_lag2"
#  [518] "ccheques_depositados_lag2"
#  [519] "mcheques_depositados_lag2"
#  [520] "ccheques_emitidos_lag2"
#  [521] "mcheques_emitidos_lag2"
#  [522] "ccheques_depositados_rechazados_lag2"
#  [523] "mcheques_depositados_rechazados_lag2"
#  [524] "ccheques_emitidos_rechazados_lag2"
#  [525] "mcheques_emitidos_rechazados_lag2"
#  [526] "tcallcenter_lag2"
#  [527] "ccallcenter_transacciones_lag2"
#  [528] "thomebanking_lag2"
#  [529] "chomebanking_transacciones_lag2"
#  [530] "ccajas_transacciones_lag2"
#  [531] "ccajas_consultas_lag2"
#  [532] "ccajas_depositos_lag2"
#  [533] "ccajas_extracciones_lag2"
#  [534] "ccajas_otras_lag2"
#  [535] "catm_trx_lag2"
#  [536] "matm_lag2"
#  [537] "catm_trx_other_lag2"
#  [538] "matm_other_lag2"
#  [539] "ctrx_quarter_lag2"
#  [540] "tmobile_app_lag2"
#  [541] "cmobile_app_trx_lag2"
#  [542] "Master_delinquency_lag2"
#  [543] "Master_status_lag2"
#  [544] "Master_mfinanciacion_limite_lag2"
#  [545] "Master_Fvencimiento_lag2"
#  [546] "Master_Finiciomora_lag2"
#  [547] "Master_msaldototal_lag2"
#  [548] "Master_msaldopesos_lag2"
#  [549] "Master_msaldodolares_lag2"
#  [550] "Master_mconsumospesos_lag2"
#  [551] "Master_mconsumosdolares_lag2"
#  [552] "Master_mlimitecompra_lag2"
#  [553] "Master_madelantopesos_lag2"
#  [554] "Master_madelantodolares_lag2"
#  [555] "Master_fultimo_cierre_lag2"
#  [556] "Master_mpagado_lag2"
#  [557] "Master_mpagospesos_lag2"
#  [558] "Master_mpagosdolares_lag2"
#  [559] "Master_fechaalta_lag2"
#  [560] "Master_mconsumototal_lag2"
#  [561] "Master_cconsumos_lag2"
#  [562] "Master_cadelantosefectivo_lag2"
#  [563] "Master_mpagominimo_lag2"
#  [564] "Visa_delinquency_lag2"
#  [565] "Visa_status_lag2"
#  [566] "Visa_mfinanciacion_limite_lag2"
#  [567] "Visa_Fvencimiento_lag2"
#  [568] "Visa_Finiciomora_lag2"
#  [569] "Visa_msaldototal_lag2"
#  [570] "Visa_msaldopesos_lag2"
#  [571] "Visa_msaldodolares_lag2"
#  [572] "Visa_mconsumospesos_lag2"
#  [573] "Visa_mconsumosdolares_lag2"
#  [574] "Visa_mlimitecompra_lag2"
#  [575] "Visa_madelantopesos_lag2"
#  [576] "Visa_madelantodolares_lag2"
#  [577] "Visa_fultimo_cierre_lag2"
#  [578] "Visa_mpagado_lag2"
#  [579] "Visa_mpagospesos_lag2"
#  [580] "Visa_mpagosdolares_lag2"
#  [581] "Visa_fechaalta_lag2"
#  [582] "Visa_mconsumototal_lag2"
#  [583] "Visa_cconsumos_lag2"
#  [584] "Visa_cadelantosefectivo_lag2"
#  [585] "Visa_mpagominimo_lag2"
#  [586] "tc_consumo_total_lag2"
#  [587] "tc_financiacionlimite_total_lag2"
#  [588] "tc_saldopesos_total_lag2"
#  [589] "tc_saldodolares_total_lag2"
#  [590] "tc_consumopesos_total_lag2"
#  [591] "tc_consumodolares_total_lag2"
#  [592] "tc_limitecompra_total_lag2"
#  [593] "tc_adelantopesos_total_lag2"
#  [594] "tc_adelantodolares_total_lag2"
#  [595] "tc_adelanto_total_lag2"
#  [596] "tc_pagado_total_lag2"
#  [597] "tc_pagadopesos_total_lag2"
#  [598] "tc_pagadodolares_total_lag2"
#  [599] "tc_saldototal_total_lag2"
#  [600] "tc_consumototal_total_lag2"
#  [601] "tc_cconsumos_total_lag2"
#  [602] "tc_morosidad_total_lag2"
#  [603] "m_plazofijo_total_lag2"
#  [604] "m_inversion1_total_lag2"
#  [605] "m_payroll_total_lag2"
#  [606] "c_payroll_total_lag2"
#  [607] "c_seguros_total_lag2"
#  [608] "m_promedio_plazofijo_total_lag2"
#  [609] "m_promedio_inversion_total_lag2"
#  [610] "m_promedio_caja_ahorro_lag2"
#  [611] "m_promedio_tarjeta_visa_consumo_por_transaccion_lag2"
#  [612] "m_promedio_tarjeta_master_consumo_por_transaccion_lag2"
#  [613] "m_promedio_prestamos_prendarios_lag2"
#  [614] "m_promedio_prestamos_hipotecarios_lag2"
#  [615] "m_promedio_inversion2_lag2"
#  [616] "m_promedio_pagodeservicios_lag2"
#  [617] "m_promedio_pagomiscuentas_lag2"
#  [618] "m_promedio_cajeros_propios_descuentos_lag2"
#  [619] "m_promedio_tarjeta_visa_descuentos_lag2"
#  [620] "m_promedio_tarjeta_master_descuentos_lag2"
#  [621] "m_promedio_comisiones_mantenimiento_lag2"
#  [622] "m_promedio_comisiones_otras_lag2"
#  [623] "m_promedio_forex_buy_lag2"
#  [624] "m_promedio_forex_sell_lag2"
#  [625] "m_promedio_transferencias_recibidas_lag2"
#  [626] "m_promedio_transferencias_emitidas_lag2"
#  [627] "m_promedio_extraccion_autoservicio_lag2"
#  [628] "m_promedio_cheques_depositados_lag2"
#  [629] "m_promedio_cheques_emitidos_lag2"
#  [630] "m_promedio_cheques_depositados_rechazados_lag2"
#  [631] "m_promedio_cheques_emitidos_rechazados_lag2"
#  [632] "m_promedio_atm_lag2"
#  [633] "m_promedio_atm_other_lag2"
#  [634] "proporcion_financiacion_master_cubierto_lag2"
#  [635] "proporcion_limite_master_cubierto_lag2"
#  [636] "proporcion_financiacion_visa_cubierto_lag2"
#  [637] "proporcion_limite_visa_cubierto_lag2"
#  [638] "proporcion_financiacion_total_cubierto_lag2"
#  [639] "proporcion_limite_total_cubierto_lag2"
#  [640] "tc_proporcion_saldo_pesos_lag2"
#  [641] "tc_proporcion_saldo_dolares_lag2"
#  [642] "tc_proporcion_consumo_pesos_lag2"
#  [643] "tc_proporcion_consumo_dolares_lag2"
#  [644] "tc_proporcion_consumo_total_limite_total_cubierto_lag2"
#  [645] "tc_proporcion_pago_pesos_lag2"
#  [646] "tc_proporcion_pago_dolares_lag2"
#  [647] "tc_proporcion_adelanto_pesos_lag2"
#  [648] "tc_proporcion_adelanto_dolares_lag2"
#  [649] "kmes_lag2"
#  [650] "ctrx_quarter_normalizado_lag2"
#  [651] "mpayroll_sobre_edad_lag2"
#  [652] "active_quarter_delta1"
#  [653] "active_quarter_delta2"
#  [654] "cliente_vip_delta1"
#  [655] "cliente_vip_delta2"
#  [656] "internet_delta1"
#  [657] "internet_delta2"
#  [658] "cliente_edad_delta1"
#  [659] "cliente_edad_delta2"
#  [660] "cliente_antiguedad_delta1"
#  [661] "cliente_antiguedad_delta2"
#  [662] "mrentabilidad_delta1"
#  [663] "mrentabilidad_delta2"
#  [664] "mrentabilidad_annual_delta1"
#  [665] "mrentabilidad_annual_delta2"
#  [666] "mcomisiones_delta1"
#  [667] "mcomisiones_delta2"
#  [668] "mactivos_margen_delta1"
#  [669] "mactivos_margen_delta2"
#  [670] "mpasivos_margen_delta1"
#  [671] "mpasivos_margen_delta2"
#  [672] "cproductos_delta1"
#  [673] "cproductos_delta2"
#  [674] "tcuentas_delta1"
#  [675] "tcuentas_delta2"
#  [676] "ccuenta_corriente_delta1"
#  [677] "ccuenta_corriente_delta2"
#  [678] "mcuenta_corriente_adicional_delta1"
#  [679] "mcuenta_corriente_adicional_delta2"
#  [680] "mcuenta_corriente_delta1"
#  [681] "mcuenta_corriente_delta2"
#  [682] "ccaja_ahorro_delta1"
#  [683] "ccaja_ahorro_delta2"
#  [684] "mcaja_ahorro_delta1"
#  [685] "mcaja_ahorro_delta2"
#  [686] "mcaja_ahorro_adicional_delta1"
#  [687] "mcaja_ahorro_adicional_delta2"
#  [688] "mcaja_ahorro_dolares_delta1"
#  [689] "mcaja_ahorro_dolares_delta2"
#  [690] "cdescubierto_preacordado_delta1"
#  [691] "cdescubierto_preacordado_delta2"
#  [692] "mcuentas_saldo_delta1"
#  [693] "mcuentas_saldo_delta2"
#  [694] "ctarjeta_debito_delta1"
#  [695] "ctarjeta_debito_delta2"
#  [696] "ctarjeta_debito_transacciones_delta1"
#  [697] "ctarjeta_debito_transacciones_delta2"
#  [698] "mautoservicio_delta1"
#  [699] "mautoservicio_delta2"
#  [700] "ctarjeta_visa_delta1"
#  [701] "ctarjeta_visa_delta2"
#  [702] "ctarjeta_visa_transacciones_delta1"
#  [703] "ctarjeta_visa_transacciones_delta2"
#  [704] "mtarjeta_visa_consumo_delta1"
#  [705] "mtarjeta_visa_consumo_delta2"
#  [706] "ctarjeta_master_delta1"
#  [707] "ctarjeta_master_delta2"
#  [708] "ctarjeta_master_transacciones_delta1"
#  [709] "ctarjeta_master_transacciones_delta2"
#  [710] "mtarjeta_master_consumo_delta1"
#  [711] "mtarjeta_master_consumo_delta2"
#  [712] "cprestamos_prendarios_delta1"
#  [713] "cprestamos_prendarios_delta2"
#  [714] "mprestamos_prendarios_delta1"
#  [715] "mprestamos_prendarios_delta2"
#  [716] "cprestamos_hipotecarios_delta1"
#  [717] "cprestamos_hipotecarios_delta2"
#  [718] "mprestamos_hipotecarios_delta1"
#  [719] "mprestamos_hipotecarios_delta2"
#  [720] "cplazo_fijo_delta1"
#  [721] "cplazo_fijo_delta2"
#  [722] "mplazo_fijo_dolares_delta1"
#  [723] "mplazo_fijo_dolares_delta2"
#  [724] "mplazo_fijo_pesos_delta1"
#  [725] "mplazo_fijo_pesos_delta2"
#  [726] "cinversion1_delta1"
# ...
#  [999] "m_promedio_inversion_total_delta2"
# [1000] "m_promedio_caja_ahorro_delta1"
# [1001] "m_promedio_caja_ahorro_delta2"
# [1002] "m_promedio_tarjeta_visa_consumo_por_transaccion_delta1"
# [1003] "m_promedio_tarjeta_visa_consumo_por_transaccion_delta2"
# [1004] "m_promedio_tarjeta_master_consumo_por_transaccion_delta1"
# [1005] "m_promedio_tarjeta_master_consumo_por_transaccion_delta2"
# [1006] "m_promedio_prestamos_prendarios_delta1"
# [1007] "m_promedio_prestamos_prendarios_delta2"
# [1008] "m_promedio_prestamos_hipotecarios_delta1"
# [1009] "m_promedio_prestamos_hipotecarios_delta2"
# [1010] "m_promedio_inversion2_delta1"
# [1011] "m_promedio_inversion2_delta2"
# [1012] "m_promedio_pagodeservicios_delta1"
# [1013] "m_promedio_pagodeservicios_delta2"
# [1014] "m_promedio_pagomiscuentas_delta1"
# [1015] "m_promedio_pagomiscuentas_delta2"
# [1016] "m_promedio_cajeros_propios_descuentos_delta1"
# [1017] "m_promedio_cajeros_propios_descuentos_delta2"
# [1018] "m_promedio_tarjeta_visa_descuentos_delta1"
# [1019] "m_promedio_tarjeta_visa_descuentos_delta2"
# [1020] "m_promedio_tarjeta_master_descuentos_delta1"
# [1021] "m_promedio_tarjeta_master_descuentos_delta2"
# [1022] "m_promedio_comisiones_mantenimiento_delta1"
# [1023] "m_promedio_comisiones_mantenimiento_delta2"
# [1024] "m_promedio_comisiones_otras_delta1"
# [1025] "m_promedio_comisiones_otras_delta2"
# [1026] "m_promedio_forex_buy_delta1"
# [1027] "m_promedio_forex_buy_delta2"
# [1028] "m_promedio_forex_sell_delta1"
# [1029] "m_promedio_forex_sell_delta2"
# [1030] "m_promedio_transferencias_recibidas_delta1"
# [1031] "m_promedio_transferencias_recibidas_delta2"
# [1032] "m_promedio_transferencias_emitidas_delta1"
# [1033] "m_promedio_transferencias_emitidas_delta2"
# [1034] "m_promedio_extraccion_autoservicio_delta1"
# [1035] "m_promedio_extraccion_autoservicio_delta2"
# [1036] "m_promedio_cheques_depositados_delta1"
# [1037] "m_promedio_cheques_depositados_delta2"
# [1038] "m_promedio_cheques_emitidos_delta1"
# [1039] "m_promedio_cheques_emitidos_delta2"
# [1040] "m_promedio_cheques_depositados_rechazados_delta1"
# [1041] "m_promedio_cheques_depositados_rechazados_delta2"
# [1042] "m_promedio_cheques_emitidos_rechazados_delta1"
# [1043] "m_promedio_cheques_emitidos_rechazados_delta2"
# [1044] "m_promedio_atm_delta1"
# [1045] "m_promedio_atm_delta2"
# [1046] "m_promedio_atm_other_delta1"
# [1047] "m_promedio_atm_other_delta2"
# [1048] "proporcion_financiacion_master_cubierto_delta1"
# [1049] "proporcion_financiacion_master_cubierto_delta2"
# [1050] "proporcion_limite_master_cubierto_delta1"
# [1051] "proporcion_limite_master_cubierto_delta2"
# [1052] "proporcion_financiacion_visa_cubierto_delta1"
# [1053] "proporcion_financiacion_visa_cubierto_delta2"
# [1054] "proporcion_limite_visa_cubierto_delta1"
# [1055] "proporcion_limite_visa_cubierto_delta2"
# [1056] "proporcion_financiacion_total_cubierto_delta1"
# [1057] "proporcion_financiacion_total_cubierto_delta2"
# [1058] "proporcion_limite_total_cubierto_delta1"
# [1059] "proporcion_limite_total_cubierto_delta2"
# [1060] "tc_proporcion_saldo_pesos_delta1"
# [1061] "tc_proporcion_saldo_pesos_delta2"
# [1062] "tc_proporcion_saldo_dolares_delta1"
# [1063] "tc_proporcion_saldo_dolares_delta2"
# [1064] "tc_proporcion_consumo_pesos_delta1"
# [1065] "tc_proporcion_consumo_pesos_delta2"
# [1066] "tc_proporcion_consumo_dolares_delta1"
# [1067] "tc_proporcion_consumo_dolares_delta2"
# [1068] "tc_proporcion_consumo_total_limite_total_cubierto_delta1"
# [1069] "tc_proporcion_consumo_total_limite_total_cubierto_delta2"
# [1070] "tc_proporcion_pago_pesos_delta1"
# [1071] "tc_proporcion_pago_pesos_delta2"
# [1072] "tc_proporcion_pago_dolares_delta1"
# [1073] "tc_proporcion_pago_dolares_delta2"
# [1074] "tc_proporcion_adelanto_pesos_delta1"
# [1075] "tc_proporcion_adelanto_pesos_delta2"
# [1076] "tc_proporcion_adelanto_dolares_delta1"
# [1077] "tc_proporcion_adelanto_dolares_delta2"
# [1078] "kmes_delta1"
# [1079] "kmes_delta2"
# [1080] "ctrx_quarter_normalizado_delta1"
# [1081] "ctrx_quarter_normalizado_delta2"
# [1082] "mpayroll_sobre_edad_delta1"
# [1083] "mpayroll_sobre_edad_delta2"
# [1084] "active_quarter_tend6"
# [1085] "cliente_vip_tend6"
# [1086] "internet_tend6"
# [1087] "cliente_edad_tend6"
# [1088] "cliente_antiguedad_tend6"
# [1089] "mrentabilidad_tend6"
# [1090] "mrentabilidad_annual_tend6"
# [1091] "mcomisiones_tend6"
# [1092] "mactivos_margen_tend6"
# [1093] "mpasivos_margen_tend6"
# [1094] "cproductos_tend6"
# [1095] "tcuentas_tend6"
# [1096] "ccuenta_corriente_tend6"
# [1097] "mcuenta_corriente_adicional_tend6"
# [1098] "mcuenta_corriente_tend6"
# [1099] "ccaja_ahorro_tend6"
# [1100] "mcaja_ahorro_tend6"
# [1101] "mcaja_ahorro_adicional_tend6"
# [1102] "mcaja_ahorro_dolares_tend6"
# [1103] "cdescubierto_preacordado_tend6"
# [1104] "mcuentas_saldo_tend6"
# [1105] "ctarjeta_debito_tend6"
# [1106] "ctarjeta_debito_transacciones_tend6"
# [1107] "mautoservicio_tend6"
# [1108] "ctarjeta_visa_tend6"
# [1109] "ctarjeta_visa_transacciones_tend6"
# [1110] "mtarjeta_visa_consumo_tend6"
# [1111] "ctarjeta_master_tend6"
# [1112] "ctarjeta_master_transacciones_tend6"
# [1113] "mtarjeta_master_consumo_tend6"
# [1114] "cprestamos_prendarios_tend6"
# [1115] "mprestamos_prendarios_tend6"
# [1116] "cprestamos_hipotecarios_tend6"
# [1117] "mprestamos_hipotecarios_tend6"
# [1118] "cplazo_fijo_tend6"
# [1119] "mplazo_fijo_dolares_tend6"
# [1120] "mplazo_fijo_pesos_tend6"
# [1121] "cinversion1_tend6"
# [1122] "minversion1_pesos_tend6"
# [1123] "minversion1_dolares_tend6"
# [1124] "cinversion2_tend6"
# [1125] "minversion2_tend6"
# [1126] "cseguro_vida_tend6"
# [1127] "cseguro_auto_tend6"
# [1128] "cseguro_vivienda_tend6"
# [1129] "cseguro_accidentes_personales_tend6"
# [1130] "ccaja_seguridad_tend6"
# [1131] "cpayroll_trx_tend6"
# [1132] "mpayroll_tend6"
# [1133] "mpayroll2_tend6"
# [1134] "cpayroll2_trx_tend6"
# [1135] "ccuenta_debitos_automaticos_tend6"
# [1136] "mcuenta_debitos_automaticos_tend6"
# [1137] "ctarjeta_visa_debitos_automaticos_tend6"
# [1138] "mttarjeta_visa_debitos_automaticos_tend6"
# [1139] "ctarjeta_master_debitos_automaticos_tend6"
# [1140] "mttarjeta_master_debitos_automaticos_tend6"
# [1141] "cpagodeservicios_tend6"
# [1142] "mpagodeservicios_tend6"
# [1143] "cpagomiscuentas_tend6"
# [1144] "mpagomiscuentas_tend6"
# [1145] "ccajeros_propios_descuentos_tend6"
# [1146] "mcajeros_propios_descuentos_tend6"
# [1147] "ctarjeta_visa_descuentos_tend6"
# [1148] "mtarjeta_visa_descuentos_tend6"
# [1149] "ctarjeta_master_descuentos_tend6"
# [1150] "mtarjeta_master_descuentos_tend6"
# [1151] "ccomisiones_mantenimiento_tend6"
# [1152] "mcomisiones_mantenimiento_tend6"
# [1153] "ccomisiones_otras_tend6"
# [1154] "mcomisiones_otras_tend6"
# [1155] "cforex_tend6"
# [1156] "cforex_buy_tend6"
# [1157] "mforex_buy_tend6"
# [1158] "cforex_sell_tend6"
# [1159] "mforex_sell_tend6"
# [1160] "ctransferencias_recibidas_tend6"
# [1161] "mtransferencias_recibidas_tend6"
# [1162] "ctransferencias_emitidas_tend6"
# [1163] "mtransferencias_emitidas_tend6"
# [1164] "cextraccion_autoservicio_tend6"
# [1165] "mextraccion_autoservicio_tend6"
# [1166] "ccheques_depositados_tend6"
# [1167] "mcheques_depositados_tend6"
# [1168] "ccheques_emitidos_tend6"
# [1169] "mcheques_emitidos_tend6"
# [1170] "ccheques_depositados_rechazados_tend6"
# [1171] "mcheques_depositados_rechazados_tend6"
# [1172] "ccheques_emitidos_rechazados_tend6"
# [1173] "mcheques_emitidos_rechazados_tend6"
# [1174] "tcallcenter_tend6"
# [1175] "ccallcenter_transacciones_tend6"
# [1176] "thomebanking_tend6"
# [1177] "chomebanking_transacciones_tend6"
# [1178] "ccajas_transacciones_tend6"
# [1179] "ccajas_consultas_tend6"
# [1180] "ccajas_depositos_tend6"
# [1181] "ccajas_extracciones_tend6"
# [1182] "ccajas_otras_tend6"
# [1183] "catm_trx_tend6"
# [1184] "matm_tend6"
# [1185] "catm_trx_other_tend6"
# [1186] "matm_other_tend6"
# [1187] "ctrx_quarter_tend6"
# [1188] "tmobile_app_tend6"
# [1189] "cmobile_app_trx_tend6"
# [1190] "Master_delinquency_tend6"
# [1191] "Master_status_tend6"
# [1192] "Master_mfinanciacion_limite_tend6"
# [1193] "Master_Fvencimiento_tend6"
# [1194] "Master_Finiciomora_tend6"
# [1195] "Master_msaldototal_tend6"
# [1196] "Master_msaldopesos_tend6"
# [1197] "Master_msaldodolares_tend6"
# [1198] "Master_mconsumospesos_tend6"
# [1199] "Master_mconsumosdolares_tend6"
# [1200] "Master_mlimitecompra_tend6"
# [1201] "Master_madelantopesos_tend6"
# [1202] "Master_madelantodolares_tend6"
# [1203] "Master_fultimo_cierre_tend6"
# [1204] "Master_mpagado_tend6"
# [1205] "Master_mpagospesos_tend6"
# [1206] "Master_mpagosdolares_tend6"
# [1207] "Master_fechaalta_tend6"
# [1208] "Master_mconsumototal_tend6"
# [1209] "Master_cconsumos_tend6"
# [1210] "Master_cadelantosefectivo_tend6"
# [1211] "Master_mpagominimo_tend6"
# [1212] "Visa_delinquency_tend6"
# [1213] "Visa_status_tend6"
# [1214] "Visa_mfinanciacion_limite_tend6"
# [1215] "Visa_Fvencimiento_tend6"
# [1216] "Visa_Finiciomora_tend6"
# [1217] "Visa_msaldototal_tend6"
# [1218] "Visa_msaldopesos_tend6"
# [1219] "Visa_msaldodolares_tend6"
# [1220] "Visa_mconsumospesos_tend6"
# [1221] "Visa_mconsumosdolares_tend6"
# [1222] "Visa_mlimitecompra_tend6"
# [1223] "Visa_madelantopesos_tend6"
# [1224] "Visa_madelantodolares_tend6"
# [1225] "Visa_fultimo_cierre_tend6"
# [1226] "Visa_mpagado_tend6"
# [1227] "Visa_mpagospesos_tend6"
# [1228] "Visa_mpagosdolares_tend6"
# [1229] "Visa_fechaalta_tend6"
# [1230] "Visa_mconsumototal_tend6"
# [1231] "Visa_cconsumos_tend6"
# [1232] "Visa_cadelantosefectivo_tend6"
# [1233] "Visa_mpagominimo_tend6"
# [1234] "tc_consumo_total_tend6"
# [1235] "tc_financiacionlimite_total_tend6"
# [1236] "tc_saldopesos_total_tend6"
# [1237] "tc_saldodolares_total_tend6"
# [1238] "tc_consumopesos_total_tend6"
# [1239] "tc_consumodolares_total_tend6"
# [1240] "tc_limitecompra_total_tend6"

# %% [markdown]
# ## Produccion

# %% [markdown]
# Las decisiones que se toman para la construccion del modelo final son:
# * Los positvos son  POS={"BAJA+1", "BAJA+2"}
# * Por experimentos en meses anteriores, se decide cortar en los 11000 registros con mayor probabildiad de POS={"BAJA+1", "BAJA+2"}
# * Utilizo *zLightGBM* con 5 canaritos por experiencia de otros experimentos presentados

# %%
# training y future
Sys.time()

PARAM$future <- c(202109)

PARAM$train_final$meses <- c(201901, 201902, 201903, 201904, 201905, 201906,
  201907, 201908, 201909, 201911, 201912,
  202001, 202002, 202003, 202004, 202005,
  202007, 202008, 202009, 202010, 202011, 202012,
  202101, 202102, 202103, 202104, 202105, 202106, 202107
)
  
PARAM$train_final$undersampling <- 0.05
# Out:
# [1] "2025-12-03 23:30:57 UTC"

# %% [markdown]
# ### Final Training Strategy

# %%
# se filtran los meses donde se entrena el modelo final

library(data.table)
setDT(dataset)

dataset_train_final <- dataset[foto_mes %in% PARAM$train_final$meses]

# %%
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train_final[, azar := runif(nrow(dataset_train_final))]
dataset_train_final[, training := 0L]

dataset_train_final[
  (azar <= PARAM$train_final$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

dataset_train_final[, azar:= NULL] # elimino la columna azar

# %% [markdown]
# ### Target Engineering

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train_final[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %% [markdown]
# ### Final Model

# %%
# utilizo  zLightGBM  la nueva libreria
if( !require("zlightgbm") ) install.packages("https://storage.googleapis.com/open-courses/dmeyf2025-e4a2/zlightgbm_4.6.0.99.tar.gz", repos= NULL, type= "source")
require("zlightgbm")
Sys.time()
# Out:
# Loading required package: zlightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘zlightgbm’”
# Installing package into ‘/home/rivas_ae97/.local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: zlightgbm
# [1] "2025-12-03 23:32:40 UTC"

# %%
# canaritos
PARAM$qcanaritos <- 5

cols0 <- copy(colnames(dataset_train_final))
filas <- nrow(dataset_train_final)

for( i in seq(PARAM$qcanaritos) ){
  dataset_train_final[, paste0("canarito_",i) := runif( filas) ]
}

# las columnas canaritos mandatoriamente van al comienzo del dataset
cols_canaritos <- copy( setdiff( colnames(dataset_train_final), cols0 ) )
setcolorder( dataset_train_final, c( cols_canaritos, cols0 ) )

Sys.time()
# Out:
# [1] "2025-12-03 23:32:45 UTC"

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train_final),
  c("clase_ternaria", "clase01", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train_final[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train_final[training == 1L, clase01],
  free_raw_data= FALSE
)

cat("filas", nrow(dtrain_final), "columnas", ncol(dtrain_final), "\n")
Sys.time()
# Out:
# filas 250131 columnas 1244
# [1] "2025-12-03 23:32:52 UTC"

# %%
# definicion de parametros

PARAM$lgbm <-  list(
  boosting= "gbdt",
  objective= "binary",
  metric= "custom",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE,
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_bin= 31L,
  min_data_in_leaf= 20L,  

  num_iterations= 9999L, 
  num_leaves= 9999L, 
  learning_rate= 1.0, 
    
  feature_fraction= 0.50,
    
  canaritos= PARAM$qcanaritos, 
  gradient_bound= 0.1  
)

Sys.time()
# Out:
# [1] "2025-12-03 23:32:56 UTC"

# %% [markdown]
# ####  Entrenamiento del modelo

# %%
# entreno el modelo

modelo_final <- lgb.train(
  data= dtrain_final,
  param= PARAM$lgbm
)

Sys.time()
# Out:
# [1] "2025-12-03 23:52:58 UTC"

# %%
# grabo el modelo generado, esto pude ser levantado por LighGBM en cualquier maquina
lgb.save(modelo_final, file="zmodelo.txt")

Sys.time()
# Out:
# [1] "2025-11-16 17:56:13 UTC"

# %% [markdown]
# ### Predict

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes %in% PARAM$future]

# penosamente, en la versión actual de zLightGBM  los campos canaritos
#  aunque no se utilizan para nada, también deben estar en el dataset donde se hace el predict()
filas <- nrow(dfuture)

for( i in seq(PARAM$qcanaritos) ){
  dfuture[, paste0("canarito_",i) := runif( filas) ]
}

prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE]),
)

# %%
# tabla de prediccion, puede ser util para futuros ensembles
#  ya que le modelo ganador va a ser un ensemble de LightGBMs

tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "e010_03_prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# ### Clasificacion

# %%
# Ordenar por probabilidad descendente
setorder(tb_prediccion, -prob)

# Cantidad de envíos
envios <- 11000

# Extraer solo los IDs
ids_envio <- tb_prediccion[1:envios, .(numero_de_cliente)]

# Archivo
archivo_csv <- paste0("e010_03_", envios, ".csv")

# Guardar 
fwrite(
  ids_envio,
  file = archivo_csv,
  col.names = FALSE,  
  sep = ","            
)
