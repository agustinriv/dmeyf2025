# %%
import duckdb
import pandas as pd

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb://

# %%
# %%sql
# create or replace table competencia_01 as
# select
#     *
# from read_csv_auto("../datasets/competencia_01.csv")
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
columnas = df.columns.tolist()
columnas = [c for c in df.columns if c not in ['numero_de_cliente', 'foto_mes', 'clase_ternaria']]

# %%
def gen_feat_2m(columnas, ventana='ventana_2'):
    tpl = """
, lag({c}, 1) OVER {w} AS lag_1_{c}
, lag({c}, 2) OVER {w} AS lag_2_{c}
, {c} - lag({c}, 1) OVER {w} AS delta_1_{c}
, {c} - lag({c}, 2) OVER {w} AS delta_2_{c}
""".strip("\n")
    return "\n".join(tpl.format(c=c, w=ventana) for c in columnas)

print(gen_feat_2m(columnas))
# Out:
# , lag(active_quarter, 1) OVER ventana_2 AS lag_1_active_quarter
# , lag(active_quarter, 2) OVER ventana_2 AS lag_2_active_quarter
# , active_quarter - lag(active_quarter, 1) OVER ventana_2 AS delta_1_active_quarter
# , active_quarter - lag(active_quarter, 2) OVER ventana_2 AS delta_2_active_quarter
# , lag(cliente_vip, 1) OVER ventana_2 AS lag_1_cliente_vip
# , lag(cliente_vip, 2) OVER ventana_2 AS lag_2_cliente_vip
# , cliente_vip - lag(cliente_vip, 1) OVER ventana_2 AS delta_1_cliente_vip
# , cliente_vip - lag(cliente_vip, 2) OVER ventana_2 AS delta_2_cliente_vip
# , lag(internet, 1) OVER ventana_2 AS lag_1_internet
# , lag(internet, 2) OVER ventana_2 AS lag_2_internet
# , internet - lag(internet, 1) OVER ventana_2 AS delta_1_internet
# , internet - lag(internet, 2) OVER ventana_2 AS delta_2_internet
# , lag(cliente_edad, 1) OVER ventana_2 AS lag_1_cliente_edad
# , lag(cliente_edad, 2) OVER ventana_2 AS lag_2_cliente_edad
# ...

# %%
# %%sql
# COPY(
#   SELECT
#     numero_de_cliente,
#     foto_mes
# , lag(active_quarter, 1) OVER ventana_2 AS lag_1_active_quarter
# , lag(active_quarter, 2) OVER ventana_2 AS lag_2_active_quarter
# , active_quarter - lag(active_quarter, 1) OVER ventana_2 AS delta_1_active_quarter
# , active_quarter - lag(active_quarter, 2) OVER ventana_2 AS delta_2_active_quarter
# , lag(cliente_vip, 1) OVER ventana_2 AS lag_1_cliente_vip
# , lag(cliente_vip, 2) OVER ventana_2 AS lag_2_cliente_vip
# , cliente_vip - lag(cliente_vip, 1) OVER ventana_2 AS delta_1_cliente_vip
# , cliente_vip - lag(cliente_vip, 2) OVER ventana_2 AS delta_2_cliente_vip
# , lag(internet, 1) OVER ventana_2 AS lag_1_internet
# , lag(internet, 2) OVER ventana_2 AS lag_2_internet
# , internet - lag(internet, 1) OVER ventana_2 AS delta_1_internet
# , internet - lag(internet, 2) OVER ventana_2 AS delta_2_internet
# , lag(cliente_edad, 1) OVER ventana_2 AS lag_1_cliente_edad
# , lag(cliente_edad, 2) OVER ventana_2 AS lag_2_cliente_edad
# , cliente_edad - lag(cliente_edad, 1) OVER ventana_2 AS delta_1_cliente_edad
# , cliente_edad - lag(cliente_edad, 2) OVER ventana_2 AS delta_2_cliente_edad
# , lag(cliente_antiguedad, 1) OVER ventana_2 AS lag_1_cliente_antiguedad
# , lag(cliente_antiguedad, 2) OVER ventana_2 AS lag_2_cliente_antiguedad
# , cliente_antiguedad - lag(cliente_antiguedad, 1) OVER ventana_2 AS delta_1_cliente_antiguedad
# , cliente_antiguedad - lag(cliente_antiguedad, 2) OVER ventana_2 AS delta_2_cliente_antiguedad
# , lag(mrentabilidad, 1) OVER ventana_2 AS lag_1_mrentabilidad
# , lag(mrentabilidad, 2) OVER ventana_2 AS lag_2_mrentabilidad
# , mrentabilidad - lag(mrentabilidad, 1) OVER ventana_2 AS delta_1_mrentabilidad
# , mrentabilidad - lag(mrentabilidad, 2) OVER ventana_2 AS delta_2_mrentabilidad
# , lag(mrentabilidad_annual, 1) OVER ventana_2 AS lag_1_mrentabilidad_annual
# , lag(mrentabilidad_annual, 2) OVER ventana_2 AS lag_2_mrentabilidad_annual
# , mrentabilidad_annual - lag(mrentabilidad_annual, 1) OVER ventana_2 AS delta_1_mrentabilidad_annual
# , mrentabilidad_annual - lag(mrentabilidad_annual, 2) OVER ventana_2 AS delta_2_mrentabilidad_annual
# , lag(mcomisiones, 1) OVER ventana_2 AS lag_1_mcomisiones
# , lag(mcomisiones, 2) OVER ventana_2 AS lag_2_mcomisiones
# , mcomisiones - lag(mcomisiones, 1) OVER ventana_2 AS delta_1_mcomisiones
# , mcomisiones - lag(mcomisiones, 2) OVER ventana_2 AS delta_2_mcomisiones
# , lag(mactivos_margen, 1) OVER ventana_2 AS lag_1_mactivos_margen
# , lag(mactivos_margen, 2) OVER ventana_2 AS lag_2_mactivos_margen
# , mactivos_margen - lag(mactivos_margen, 1) OVER ventana_2 AS delta_1_mactivos_margen
# , mactivos_margen - lag(mactivos_margen, 2) OVER ventana_2 AS delta_2_mactivos_margen
# , lag(mpasivos_margen, 1) OVER ventana_2 AS lag_1_mpasivos_margen
# , lag(mpasivos_margen, 2) OVER ventana_2 AS lag_2_mpasivos_margen
# , mpasivos_margen - lag(mpasivos_margen, 1) OVER ventana_2 AS delta_1_mpasivos_margen
# , mpasivos_margen - lag(mpasivos_margen, 2) OVER ventana_2 AS delta_2_mpasivos_margen
# , lag(cproductos, 1) OVER ventana_2 AS lag_1_cproductos
# , lag(cproductos, 2) OVER ventana_2 AS lag_2_cproductos
# , cproductos - lag(cproductos, 1) OVER ventana_2 AS delta_1_cproductos
# , cproductos - lag(cproductos, 2) OVER ventana_2 AS delta_2_cproductos
# , lag(tcuentas, 1) OVER ventana_2 AS lag_1_tcuentas
# , lag(tcuentas, 2) OVER ventana_2 AS lag_2_tcuentas
# , tcuentas - lag(tcuentas, 1) OVER ventana_2 AS delta_1_tcuentas
# , tcuentas - lag(tcuentas, 2) OVER ventana_2 AS delta_2_tcuentas
# , lag(ccuenta_corriente, 1) OVER ventana_2 AS lag_1_ccuenta_corriente
# , lag(ccuenta_corriente, 2) OVER ventana_2 AS lag_2_ccuenta_corriente
# , ccuenta_corriente - lag(ccuenta_corriente, 1) OVER ventana_2 AS delta_1_ccuenta_corriente
# , ccuenta_corriente - lag(ccuenta_corriente, 2) OVER ventana_2 AS delta_2_ccuenta_corriente
# , lag(mcuenta_corriente_adicional, 1) OVER ventana_2 AS lag_1_mcuenta_corriente_adicional
# , lag(mcuenta_corriente_adicional, 2) OVER ventana_2 AS lag_2_mcuenta_corriente_adicional
# , mcuenta_corriente_adicional - lag(mcuenta_corriente_adicional, 1) OVER ventana_2 AS delta_1_mcuenta_corriente_adicional
# , mcuenta_corriente_adicional - lag(mcuenta_corriente_adicional, 2) OVER ventana_2 AS delta_2_mcuenta_corriente_adicional
# , lag(mcuenta_corriente, 1) OVER ventana_2 AS lag_1_mcuenta_corriente
# , lag(mcuenta_corriente, 2) OVER ventana_2 AS lag_2_mcuenta_corriente
# , mcuenta_corriente - lag(mcuenta_corriente, 1) OVER ventana_2 AS delta_1_mcuenta_corriente
# , mcuenta_corriente - lag(mcuenta_corriente, 2) OVER ventana_2 AS delta_2_mcuenta_corriente
# , lag(ccaja_ahorro, 1) OVER ventana_2 AS lag_1_ccaja_ahorro
# , lag(ccaja_ahorro, 2) OVER ventana_2 AS lag_2_ccaja_ahorro
# , ccaja_ahorro - lag(ccaja_ahorro, 1) OVER ventana_2 AS delta_1_ccaja_ahorro
# , ccaja_ahorro - lag(ccaja_ahorro, 2) OVER ventana_2 AS delta_2_ccaja_ahorro
# , lag(mcaja_ahorro, 1) OVER ventana_2 AS lag_1_mcaja_ahorro
# , lag(mcaja_ahorro, 2) OVER ventana_2 AS lag_2_mcaja_ahorro
# , mcaja_ahorro - lag(mcaja_ahorro, 1) OVER ventana_2 AS delta_1_mcaja_ahorro
# , mcaja_ahorro - lag(mcaja_ahorro, 2) OVER ventana_2 AS delta_2_mcaja_ahorro
# , lag(mcaja_ahorro_adicional, 1) OVER ventana_2 AS lag_1_mcaja_ahorro_adicional
# , lag(mcaja_ahorro_adicional, 2) OVER ventana_2 AS lag_2_mcaja_ahorro_adicional
# , mcaja_ahorro_adicional - lag(mcaja_ahorro_adicional, 1) OVER ventana_2 AS delta_1_mcaja_ahorro_adicional
# , mcaja_ahorro_adicional - lag(mcaja_ahorro_adicional, 2) OVER ventana_2 AS delta_2_mcaja_ahorro_adicional
# , lag(mcaja_ahorro_dolares, 1) OVER ventana_2 AS lag_1_mcaja_ahorro_dolares
# , lag(mcaja_ahorro_dolares, 2) OVER ventana_2 AS lag_2_mcaja_ahorro_dolares
# , mcaja_ahorro_dolares - lag(mcaja_ahorro_dolares, 1) OVER ventana_2 AS delta_1_mcaja_ahorro_dolares
# , mcaja_ahorro_dolares - lag(mcaja_ahorro_dolares, 2) OVER ventana_2 AS delta_2_mcaja_ahorro_dolares
# , lag(cdescubierto_preacordado, 1) OVER ventana_2 AS lag_1_cdescubierto_preacordado
# , lag(cdescubierto_preacordado, 2) OVER ventana_2 AS lag_2_cdescubierto_preacordado
# , cdescubierto_preacordado - lag(cdescubierto_preacordado, 1) OVER ventana_2 AS delta_1_cdescubierto_preacordado
# , cdescubierto_preacordado - lag(cdescubierto_preacordado, 2) OVER ventana_2 AS delta_2_cdescubierto_preacordado
# , lag(mcuentas_saldo, 1) OVER ventana_2 AS lag_1_mcuentas_saldo
# , lag(mcuentas_saldo, 2) OVER ventana_2 AS lag_2_mcuentas_saldo
# , mcuentas_saldo - lag(mcuentas_saldo, 1) OVER ventana_2 AS delta_1_mcuentas_saldo
# , mcuentas_saldo - lag(mcuentas_saldo, 2) OVER ventana_2 AS delta_2_mcuentas_saldo
# , lag(ctarjeta_debito, 1) OVER ventana_2 AS lag_1_ctarjeta_debito
# , lag(ctarjeta_debito, 2) OVER ventana_2 AS lag_2_ctarjeta_debito
# , ctarjeta_debito - lag(ctarjeta_debito, 1) OVER ventana_2 AS delta_1_ctarjeta_debito
# , ctarjeta_debito - lag(ctarjeta_debito, 2) OVER ventana_2 AS delta_2_ctarjeta_debito
# , lag(ctarjeta_debito_transacciones, 1) OVER ventana_2 AS lag_1_ctarjeta_debito_transacciones
# , lag(ctarjeta_debito_transacciones, 2) OVER ventana_2 AS lag_2_ctarjeta_debito_transacciones
# , ctarjeta_debito_transacciones - lag(ctarjeta_debito_transacciones, 1) OVER ventana_2 AS delta_1_ctarjeta_debito_transacciones
# , ctarjeta_debito_transacciones - lag(ctarjeta_debito_transacciones, 2) OVER ventana_2 AS delta_2_ctarjeta_debito_transacciones
# , lag(mautoservicio, 1) OVER ventana_2 AS lag_1_mautoservicio
# , lag(mautoservicio, 2) OVER ventana_2 AS lag_2_mautoservicio
# , mautoservicio - lag(mautoservicio, 1) OVER ventana_2 AS delta_1_mautoservicio
# , mautoservicio - lag(mautoservicio, 2) OVER ventana_2 AS delta_2_mautoservicio
# , lag(ctarjeta_visa, 1) OVER ventana_2 AS lag_1_ctarjeta_visa
# , lag(ctarjeta_visa, 2) OVER ventana_2 AS lag_2_ctarjeta_visa
# , ctarjeta_visa - lag(ctarjeta_visa, 1) OVER ventana_2 AS delta_1_ctarjeta_visa
# , ctarjeta_visa - lag(ctarjeta_visa, 2) OVER ventana_2 AS delta_2_ctarjeta_visa
# , lag(ctarjeta_visa_transacciones, 1) OVER ventana_2 AS lag_1_ctarjeta_visa_transacciones
# , lag(ctarjeta_visa_transacciones, 2) OVER ventana_2 AS lag_2_ctarjeta_visa_transacciones
# , ctarjeta_visa_transacciones - lag(ctarjeta_visa_transacciones, 1) OVER ventana_2 AS delta_1_ctarjeta_visa_transacciones
# , ctarjeta_visa_transacciones - lag(ctarjeta_visa_transacciones, 2) OVER ventana_2 AS delta_2_ctarjeta_visa_transacciones
# , lag(mtarjeta_visa_consumo, 1) OVER ventana_2 AS lag_1_mtarjeta_visa_consumo
# , lag(mtarjeta_visa_consumo, 2) OVER ventana_2 AS lag_2_mtarjeta_visa_consumo
# , mtarjeta_visa_consumo - lag(mtarjeta_visa_consumo, 1) OVER ventana_2 AS delta_1_mtarjeta_visa_consumo
# , mtarjeta_visa_consumo - lag(mtarjeta_visa_consumo, 2) OVER ventana_2 AS delta_2_mtarjeta_visa_consumo
# , lag(ctarjeta_master, 1) OVER ventana_2 AS lag_1_ctarjeta_master
# , lag(ctarjeta_master, 2) OVER ventana_2 AS lag_2_ctarjeta_master
# , ctarjeta_master - lag(ctarjeta_master, 1) OVER ventana_2 AS delta_1_ctarjeta_master
# , ctarjeta_master - lag(ctarjeta_master, 2) OVER ventana_2 AS delta_2_ctarjeta_master
# , lag(ctarjeta_master_transacciones, 1) OVER ventana_2 AS lag_1_ctarjeta_master_transacciones
# , lag(ctarjeta_master_transacciones, 2) OVER ventana_2 AS lag_2_ctarjeta_master_transacciones
# , ctarjeta_master_transacciones - lag(ctarjeta_master_transacciones, 1) OVER ventana_2 AS delta_1_ctarjeta_master_transacciones
# , ctarjeta_master_transacciones - lag(ctarjeta_master_transacciones, 2) OVER ventana_2 AS delta_2_ctarjeta_master_transacciones
# , lag(mtarjeta_master_consumo, 1) OVER ventana_2 AS lag_1_mtarjeta_master_consumo
# , lag(mtarjeta_master_consumo, 2) OVER ventana_2 AS lag_2_mtarjeta_master_consumo
# , mtarjeta_master_consumo - lag(mtarjeta_master_consumo, 1) OVER ventana_2 AS delta_1_mtarjeta_master_consumo
# , mtarjeta_master_consumo - lag(mtarjeta_master_consumo, 2) OVER ventana_2 AS delta_2_mtarjeta_master_consumo
# , lag(cprestamos_personales, 1) OVER ventana_2 AS lag_1_cprestamos_personales
# , lag(cprestamos_personales, 2) OVER ventana_2 AS lag_2_cprestamos_personales
# , cprestamos_personales - lag(cprestamos_personales, 1) OVER ventana_2 AS delta_1_cprestamos_personales
# , cprestamos_personales - lag(cprestamos_personales, 2) OVER ventana_2 AS delta_2_cprestamos_personales
# , lag(mprestamos_personales, 1) OVER ventana_2 AS lag_1_mprestamos_personales
# , lag(mprestamos_personales, 2) OVER ventana_2 AS lag_2_mprestamos_personales
# , mprestamos_personales - lag(mprestamos_personales, 1) OVER ventana_2 AS delta_1_mprestamos_personales
# , mprestamos_personales - lag(mprestamos_personales, 2) OVER ventana_2 AS delta_2_mprestamos_personales
# , lag(cprestamos_prendarios, 1) OVER ventana_2 AS lag_1_cprestamos_prendarios
# , lag(cprestamos_prendarios, 2) OVER ventana_2 AS lag_2_cprestamos_prendarios
# , cprestamos_prendarios - lag(cprestamos_prendarios, 1) OVER ventana_2 AS delta_1_cprestamos_prendarios
# , cprestamos_prendarios - lag(cprestamos_prendarios, 2) OVER ventana_2 AS delta_2_cprestamos_prendarios
# , lag(mprestamos_prendarios, 1) OVER ventana_2 AS lag_1_mprestamos_prendarios
# , lag(mprestamos_prendarios, 2) OVER ventana_2 AS lag_2_mprestamos_prendarios
# , mprestamos_prendarios - lag(mprestamos_prendarios, 1) OVER ventana_2 AS delta_1_mprestamos_prendarios
# , mprestamos_prendarios - lag(mprestamos_prendarios, 2) OVER ventana_2 AS delta_2_mprestamos_prendarios
# , lag(cprestamos_hipotecarios, 1) OVER ventana_2 AS lag_1_cprestamos_hipotecarios
# , lag(cprestamos_hipotecarios, 2) OVER ventana_2 AS lag_2_cprestamos_hipotecarios
# , cprestamos_hipotecarios - lag(cprestamos_hipotecarios, 1) OVER ventana_2 AS delta_1_cprestamos_hipotecarios
# , cprestamos_hipotecarios - lag(cprestamos_hipotecarios, 2) OVER ventana_2 AS delta_2_cprestamos_hipotecarios
# , lag(mprestamos_hipotecarios, 1) OVER ventana_2 AS lag_1_mprestamos_hipotecarios
# , lag(mprestamos_hipotecarios, 2) OVER ventana_2 AS lag_2_mprestamos_hipotecarios
# , mprestamos_hipotecarios - lag(mprestamos_hipotecarios, 1) OVER ventana_2 AS delta_1_mprestamos_hipotecarios
# , mprestamos_hipotecarios - lag(mprestamos_hipotecarios, 2) OVER ventana_2 AS delta_2_mprestamos_hipotecarios
# , lag(cplazo_fijo, 1) OVER ventana_2 AS lag_1_cplazo_fijo
# , lag(cplazo_fijo, 2) OVER ventana_2 AS lag_2_cplazo_fijo
# , cplazo_fijo - lag(cplazo_fijo, 1) OVER ventana_2 AS delta_1_cplazo_fijo
# , cplazo_fijo - lag(cplazo_fijo, 2) OVER ventana_2 AS delta_2_cplazo_fijo
# , lag(mplazo_fijo_dolares, 1) OVER ventana_2 AS lag_1_mplazo_fijo_dolares
# , lag(mplazo_fijo_dolares, 2) OVER ventana_2 AS lag_2_mplazo_fijo_dolares
# , mplazo_fijo_dolares - lag(mplazo_fijo_dolares, 1) OVER ventana_2 AS delta_1_mplazo_fijo_dolares
# , mplazo_fijo_dolares - lag(mplazo_fijo_dolares, 2) OVER ventana_2 AS delta_2_mplazo_fijo_dolares
# , lag(mplazo_fijo_pesos, 1) OVER ventana_2 AS lag_1_mplazo_fijo_pesos
# , lag(mplazo_fijo_pesos, 2) OVER ventana_2 AS lag_2_mplazo_fijo_pesos
# , mplazo_fijo_pesos - lag(mplazo_fijo_pesos, 1) OVER ventana_2 AS delta_1_mplazo_fijo_pesos
# , mplazo_fijo_pesos - lag(mplazo_fijo_pesos, 2) OVER ventana_2 AS delta_2_mplazo_fijo_pesos
# , lag(cinversion1, 1) OVER ventana_2 AS lag_1_cinversion1
# , lag(cinversion1, 2) OVER ventana_2 AS lag_2_cinversion1
# , cinversion1 - lag(cinversion1, 1) OVER ventana_2 AS delta_1_cinversion1
# , cinversion1 - lag(cinversion1, 2) OVER ventana_2 AS delta_2_cinversion1
# , lag(minversion1_pesos, 1) OVER ventana_2 AS lag_1_minversion1_pesos
# , lag(minversion1_pesos, 2) OVER ventana_2 AS lag_2_minversion1_pesos
# , minversion1_pesos - lag(minversion1_pesos, 1) OVER ventana_2 AS delta_1_minversion1_pesos
# , minversion1_pesos - lag(minversion1_pesos, 2) OVER ventana_2 AS delta_2_minversion1_pesos
# , lag(minversion1_dolares, 1) OVER ventana_2 AS lag_1_minversion1_dolares
# , lag(minversion1_dolares, 2) OVER ventana_2 AS lag_2_minversion1_dolares
# , minversion1_dolares - lag(minversion1_dolares, 1) OVER ventana_2 AS delta_1_minversion1_dolares
# , minversion1_dolares - lag(minversion1_dolares, 2) OVER ventana_2 AS delta_2_minversion1_dolares
# , lag(cinversion2, 1) OVER ventana_2 AS lag_1_cinversion2
# , lag(cinversion2, 2) OVER ventana_2 AS lag_2_cinversion2
# , cinversion2 - lag(cinversion2, 1) OVER ventana_2 AS delta_1_cinversion2
# , cinversion2 - lag(cinversion2, 2) OVER ventana_2 AS delta_2_cinversion2
# , lag(minversion2, 1) OVER ventana_2 AS lag_1_minversion2
# , lag(minversion2, 2) OVER ventana_2 AS lag_2_minversion2
# , minversion2 - lag(minversion2, 1) OVER ventana_2 AS delta_1_minversion2
# , minversion2 - lag(minversion2, 2) OVER ventana_2 AS delta_2_minversion2
# , lag(cseguro_vida, 1) OVER ventana_2 AS lag_1_cseguro_vida
# , lag(cseguro_vida, 2) OVER ventana_2 AS lag_2_cseguro_vida
# , cseguro_vida - lag(cseguro_vida, 1) OVER ventana_2 AS delta_1_cseguro_vida
# , cseguro_vida - lag(cseguro_vida, 2) OVER ventana_2 AS delta_2_cseguro_vida
# , lag(cseguro_auto, 1) OVER ventana_2 AS lag_1_cseguro_auto
# , lag(cseguro_auto, 2) OVER ventana_2 AS lag_2_cseguro_auto
# , cseguro_auto - lag(cseguro_auto, 1) OVER ventana_2 AS delta_1_cseguro_auto
# , cseguro_auto - lag(cseguro_auto, 2) OVER ventana_2 AS delta_2_cseguro_auto
# , lag(cseguro_vivienda, 1) OVER ventana_2 AS lag_1_cseguro_vivienda
# , lag(cseguro_vivienda, 2) OVER ventana_2 AS lag_2_cseguro_vivienda
# , cseguro_vivienda - lag(cseguro_vivienda, 1) OVER ventana_2 AS delta_1_cseguro_vivienda
# , cseguro_vivienda - lag(cseguro_vivienda, 2) OVER ventana_2 AS delta_2_cseguro_vivienda
# , lag(cseguro_accidentes_personales, 1) OVER ventana_2 AS lag_1_cseguro_accidentes_personales
# , lag(cseguro_accidentes_personales, 2) OVER ventana_2 AS lag_2_cseguro_accidentes_personales
# , cseguro_accidentes_personales - lag(cseguro_accidentes_personales, 1) OVER ventana_2 AS delta_1_cseguro_accidentes_personales
# , cseguro_accidentes_personales - lag(cseguro_accidentes_personales, 2) OVER ventana_2 AS delta_2_cseguro_accidentes_personales
# , lag(ccaja_seguridad, 1) OVER ventana_2 AS lag_1_ccaja_seguridad
# , lag(ccaja_seguridad, 2) OVER ventana_2 AS lag_2_ccaja_seguridad
# , ccaja_seguridad - lag(ccaja_seguridad, 1) OVER ventana_2 AS delta_1_ccaja_seguridad
# , ccaja_seguridad - lag(ccaja_seguridad, 2) OVER ventana_2 AS delta_2_ccaja_seguridad
# , lag(cpayroll_trx, 1) OVER ventana_2 AS lag_1_cpayroll_trx
# , lag(cpayroll_trx, 2) OVER ventana_2 AS lag_2_cpayroll_trx
# , cpayroll_trx - lag(cpayroll_trx, 1) OVER ventana_2 AS delta_1_cpayroll_trx
# , cpayroll_trx - lag(cpayroll_trx, 2) OVER ventana_2 AS delta_2_cpayroll_trx
# , lag(mpayroll, 1) OVER ventana_2 AS lag_1_mpayroll
# , lag(mpayroll, 2) OVER ventana_2 AS lag_2_mpayroll
# , mpayroll - lag(mpayroll, 1) OVER ventana_2 AS delta_1_mpayroll
# , mpayroll - lag(mpayroll, 2) OVER ventana_2 AS delta_2_mpayroll
# , lag(mpayroll2, 1) OVER ventana_2 AS lag_1_mpayroll2
# , lag(mpayroll2, 2) OVER ventana_2 AS lag_2_mpayroll2
# , mpayroll2 - lag(mpayroll2, 1) OVER ventana_2 AS delta_1_mpayroll2
# , mpayroll2 - lag(mpayroll2, 2) OVER ventana_2 AS delta_2_mpayroll2
# , lag(cpayroll2_trx, 1) OVER ventana_2 AS lag_1_cpayroll2_trx
# , lag(cpayroll2_trx, 2) OVER ventana_2 AS lag_2_cpayroll2_trx
# , cpayroll2_trx - lag(cpayroll2_trx, 1) OVER ventana_2 AS delta_1_cpayroll2_trx
# , cpayroll2_trx - lag(cpayroll2_trx, 2) OVER ventana_2 AS delta_2_cpayroll2_trx
# , lag(ccuenta_debitos_automaticos, 1) OVER ventana_2 AS lag_1_ccuenta_debitos_automaticos
# , lag(ccuenta_debitos_automaticos, 2) OVER ventana_2 AS lag_2_ccuenta_debitos_automaticos
# , ccuenta_debitos_automaticos - lag(ccuenta_debitos_automaticos, 1) OVER ventana_2 AS delta_1_ccuenta_debitos_automaticos
# , ccuenta_debitos_automaticos - lag(ccuenta_debitos_automaticos, 2) OVER ventana_2 AS delta_2_ccuenta_debitos_automaticos
# , lag(mcuenta_debitos_automaticos, 1) OVER ventana_2 AS lag_1_mcuenta_debitos_automaticos
# , lag(mcuenta_debitos_automaticos, 2) OVER ventana_2 AS lag_2_mcuenta_debitos_automaticos
# , mcuenta_debitos_automaticos - lag(mcuenta_debitos_automaticos, 1) OVER ventana_2 AS delta_1_mcuenta_debitos_automaticos
# , mcuenta_debitos_automaticos - lag(mcuenta_debitos_automaticos, 2) OVER ventana_2 AS delta_2_mcuenta_debitos_automaticos
# , lag(ctarjeta_visa_debitos_automaticos, 1) OVER ventana_2 AS lag_1_ctarjeta_visa_debitos_automaticos
# , lag(ctarjeta_visa_debitos_automaticos, 2) OVER ventana_2 AS lag_2_ctarjeta_visa_debitos_automaticos
# , ctarjeta_visa_debitos_automaticos - lag(ctarjeta_visa_debitos_automaticos, 1) OVER ventana_2 AS delta_1_ctarjeta_visa_debitos_automaticos
# , ctarjeta_visa_debitos_automaticos - lag(ctarjeta_visa_debitos_automaticos, 2) OVER ventana_2 AS delta_2_ctarjeta_visa_debitos_automaticos
# , lag(mttarjeta_visa_debitos_automaticos, 1) OVER ventana_2 AS lag_1_mttarjeta_visa_debitos_automaticos
# , lag(mttarjeta_visa_debitos_automaticos, 2) OVER ventana_2 AS lag_2_mttarjeta_visa_debitos_automaticos
# , mttarjeta_visa_debitos_automaticos - lag(mttarjeta_visa_debitos_automaticos, 1) OVER ventana_2 AS delta_1_mttarjeta_visa_debitos_automaticos
# , mttarjeta_visa_debitos_automaticos - lag(mttarjeta_visa_debitos_automaticos, 2) OVER ventana_2 AS delta_2_mttarjeta_visa_debitos_automaticos
# , lag(ctarjeta_master_debitos_automaticos, 1) OVER ventana_2 AS lag_1_ctarjeta_master_debitos_automaticos
# , lag(ctarjeta_master_debitos_automaticos, 2) OVER ventana_2 AS lag_2_ctarjeta_master_debitos_automaticos
# , ctarjeta_master_debitos_automaticos - lag(ctarjeta_master_debitos_automaticos, 1) OVER ventana_2 AS delta_1_ctarjeta_master_debitos_automaticos
# , ctarjeta_master_debitos_automaticos - lag(ctarjeta_master_debitos_automaticos, 2) OVER ventana_2 AS delta_2_ctarjeta_master_debitos_automaticos
# , lag(mttarjeta_master_debitos_automaticos, 1) OVER ventana_2 AS lag_1_mttarjeta_master_debitos_automaticos
# , lag(mttarjeta_master_debitos_automaticos, 2) OVER ventana_2 AS lag_2_mttarjeta_master_debitos_automaticos
# , mttarjeta_master_debitos_automaticos - lag(mttarjeta_master_debitos_automaticos, 1) OVER ventana_2 AS delta_1_mttarjeta_master_debitos_automaticos
# , mttarjeta_master_debitos_automaticos - lag(mttarjeta_master_debitos_automaticos, 2) OVER ventana_2 AS delta_2_mttarjeta_master_debitos_automaticos
# , lag(cpagodeservicios, 1) OVER ventana_2 AS lag_1_cpagodeservicios
# , lag(cpagodeservicios, 2) OVER ventana_2 AS lag_2_cpagodeservicios
# , cpagodeservicios - lag(cpagodeservicios, 1) OVER ventana_2 AS delta_1_cpagodeservicios
# , cpagodeservicios - lag(cpagodeservicios, 2) OVER ventana_2 AS delta_2_cpagodeservicios
# , lag(mpagodeservicios, 1) OVER ventana_2 AS lag_1_mpagodeservicios
# , lag(mpagodeservicios, 2) OVER ventana_2 AS lag_2_mpagodeservicios
# , mpagodeservicios - lag(mpagodeservicios, 1) OVER ventana_2 AS delta_1_mpagodeservicios
# , mpagodeservicios - lag(mpagodeservicios, 2) OVER ventana_2 AS delta_2_mpagodeservicios
# , lag(cpagomiscuentas, 1) OVER ventana_2 AS lag_1_cpagomiscuentas
# , lag(cpagomiscuentas, 2) OVER ventana_2 AS lag_2_cpagomiscuentas
# , cpagomiscuentas - lag(cpagomiscuentas, 1) OVER ventana_2 AS delta_1_cpagomiscuentas
# , cpagomiscuentas - lag(cpagomiscuentas, 2) OVER ventana_2 AS delta_2_cpagomiscuentas
# , lag(mpagomiscuentas, 1) OVER ventana_2 AS lag_1_mpagomiscuentas
# , lag(mpagomiscuentas, 2) OVER ventana_2 AS lag_2_mpagomiscuentas
# , mpagomiscuentas - lag(mpagomiscuentas, 1) OVER ventana_2 AS delta_1_mpagomiscuentas
# , mpagomiscuentas - lag(mpagomiscuentas, 2) OVER ventana_2 AS delta_2_mpagomiscuentas
# , lag(ccajeros_propios_descuentos, 1) OVER ventana_2 AS lag_1_ccajeros_propios_descuentos
# , lag(ccajeros_propios_descuentos, 2) OVER ventana_2 AS lag_2_ccajeros_propios_descuentos
# , ccajeros_propios_descuentos - lag(ccajeros_propios_descuentos, 1) OVER ventana_2 AS delta_1_ccajeros_propios_descuentos
# , ccajeros_propios_descuentos - lag(ccajeros_propios_descuentos, 2) OVER ventana_2 AS delta_2_ccajeros_propios_descuentos
# , lag(mcajeros_propios_descuentos, 1) OVER ventana_2 AS lag_1_mcajeros_propios_descuentos
# , lag(mcajeros_propios_descuentos, 2) OVER ventana_2 AS lag_2_mcajeros_propios_descuentos
# , mcajeros_propios_descuentos - lag(mcajeros_propios_descuentos, 1) OVER ventana_2 AS delta_1_mcajeros_propios_descuentos
# , mcajeros_propios_descuentos - lag(mcajeros_propios_descuentos, 2) OVER ventana_2 AS delta_2_mcajeros_propios_descuentos
# , lag(ctarjeta_visa_descuentos, 1) OVER ventana_2 AS lag_1_ctarjeta_visa_descuentos
# , lag(ctarjeta_visa_descuentos, 2) OVER ventana_2 AS lag_2_ctarjeta_visa_descuentos
# , ctarjeta_visa_descuentos - lag(ctarjeta_visa_descuentos, 1) OVER ventana_2 AS delta_1_ctarjeta_visa_descuentos
# , ctarjeta_visa_descuentos - lag(ctarjeta_visa_descuentos, 2) OVER ventana_2 AS delta_2_ctarjeta_visa_descuentos
# , lag(mtarjeta_visa_descuentos, 1) OVER ventana_2 AS lag_1_mtarjeta_visa_descuentos
# , lag(mtarjeta_visa_descuentos, 2) OVER ventana_2 AS lag_2_mtarjeta_visa_descuentos
# , mtarjeta_visa_descuentos - lag(mtarjeta_visa_descuentos, 1) OVER ventana_2 AS delta_1_mtarjeta_visa_descuentos
# , mtarjeta_visa_descuentos - lag(mtarjeta_visa_descuentos, 2) OVER ventana_2 AS delta_2_mtarjeta_visa_descuentos
# , lag(ctarjeta_master_descuentos, 1) OVER ventana_2 AS lag_1_ctarjeta_master_descuentos
# , lag(ctarjeta_master_descuentos, 2) OVER ventana_2 AS lag_2_ctarjeta_master_descuentos
# , ctarjeta_master_descuentos - lag(ctarjeta_master_descuentos, 1) OVER ventana_2 AS delta_1_ctarjeta_master_descuentos
# , ctarjeta_master_descuentos - lag(ctarjeta_master_descuentos, 2) OVER ventana_2 AS delta_2_ctarjeta_master_descuentos
# , lag(mtarjeta_master_descuentos, 1) OVER ventana_2 AS lag_1_mtarjeta_master_descuentos
# , lag(mtarjeta_master_descuentos, 2) OVER ventana_2 AS lag_2_mtarjeta_master_descuentos
# , mtarjeta_master_descuentos - lag(mtarjeta_master_descuentos, 1) OVER ventana_2 AS delta_1_mtarjeta_master_descuentos
# , mtarjeta_master_descuentos - lag(mtarjeta_master_descuentos, 2) OVER ventana_2 AS delta_2_mtarjeta_master_descuentos
# , lag(ccomisiones_mantenimiento, 1) OVER ventana_2 AS lag_1_ccomisiones_mantenimiento
# , lag(ccomisiones_mantenimiento, 2) OVER ventana_2 AS lag_2_ccomisiones_mantenimiento
# , ccomisiones_mantenimiento - lag(ccomisiones_mantenimiento, 1) OVER ventana_2 AS delta_1_ccomisiones_mantenimiento
# , ccomisiones_mantenimiento - lag(ccomisiones_mantenimiento, 2) OVER ventana_2 AS delta_2_ccomisiones_mantenimiento
# , lag(mcomisiones_mantenimiento, 1) OVER ventana_2 AS lag_1_mcomisiones_mantenimiento
# , lag(mcomisiones_mantenimiento, 2) OVER ventana_2 AS lag_2_mcomisiones_mantenimiento
# , mcomisiones_mantenimiento - lag(mcomisiones_mantenimiento, 1) OVER ventana_2 AS delta_1_mcomisiones_mantenimiento
# , mcomisiones_mantenimiento - lag(mcomisiones_mantenimiento, 2) OVER ventana_2 AS delta_2_mcomisiones_mantenimiento
# , lag(ccomisiones_otras, 1) OVER ventana_2 AS lag_1_ccomisiones_otras
# , lag(ccomisiones_otras, 2) OVER ventana_2 AS lag_2_ccomisiones_otras
# , ccomisiones_otras - lag(ccomisiones_otras, 1) OVER ventana_2 AS delta_1_ccomisiones_otras
# , ccomisiones_otras - lag(ccomisiones_otras, 2) OVER ventana_2 AS delta_2_ccomisiones_otras
# , lag(mcomisiones_otras, 1) OVER ventana_2 AS lag_1_mcomisiones_otras
# , lag(mcomisiones_otras, 2) OVER ventana_2 AS lag_2_mcomisiones_otras
# , mcomisiones_otras - lag(mcomisiones_otras, 1) OVER ventana_2 AS delta_1_mcomisiones_otras
# , mcomisiones_otras - lag(mcomisiones_otras, 2) OVER ventana_2 AS delta_2_mcomisiones_otras
# , lag(cforex, 1) OVER ventana_2 AS lag_1_cforex
# , lag(cforex, 2) OVER ventana_2 AS lag_2_cforex
# , cforex - lag(cforex, 1) OVER ventana_2 AS delta_1_cforex
# , cforex - lag(cforex, 2) OVER ventana_2 AS delta_2_cforex
# , lag(cforex_buy, 1) OVER ventana_2 AS lag_1_cforex_buy
# , lag(cforex_buy, 2) OVER ventana_2 AS lag_2_cforex_buy
# , cforex_buy - lag(cforex_buy, 1) OVER ventana_2 AS delta_1_cforex_buy
# , cforex_buy - lag(cforex_buy, 2) OVER ventana_2 AS delta_2_cforex_buy
# , lag(mforex_buy, 1) OVER ventana_2 AS lag_1_mforex_buy
# , lag(mforex_buy, 2) OVER ventana_2 AS lag_2_mforex_buy
# , mforex_buy - lag(mforex_buy, 1) OVER ventana_2 AS delta_1_mforex_buy
# , mforex_buy - lag(mforex_buy, 2) OVER ventana_2 AS delta_2_mforex_buy
# , lag(cforex_sell, 1) OVER ventana_2 AS lag_1_cforex_sell
# , lag(cforex_sell, 2) OVER ventana_2 AS lag_2_cforex_sell
# , cforex_sell - lag(cforex_sell, 1) OVER ventana_2 AS delta_1_cforex_sell
# , cforex_sell - lag(cforex_sell, 2) OVER ventana_2 AS delta_2_cforex_sell
# , lag(mforex_sell, 1) OVER ventana_2 AS lag_1_mforex_sell
# , lag(mforex_sell, 2) OVER ventana_2 AS lag_2_mforex_sell
# , mforex_sell - lag(mforex_sell, 1) OVER ventana_2 AS delta_1_mforex_sell
# , mforex_sell - lag(mforex_sell, 2) OVER ventana_2 AS delta_2_mforex_sell
# , lag(ctransferencias_recibidas, 1) OVER ventana_2 AS lag_1_ctransferencias_recibidas
# , lag(ctransferencias_recibidas, 2) OVER ventana_2 AS lag_2_ctransferencias_recibidas
# , ctransferencias_recibidas - lag(ctransferencias_recibidas, 1) OVER ventana_2 AS delta_1_ctransferencias_recibidas
# , ctransferencias_recibidas - lag(ctransferencias_recibidas, 2) OVER ventana_2 AS delta_2_ctransferencias_recibidas
# , lag(mtransferencias_recibidas, 1) OVER ventana_2 AS lag_1_mtransferencias_recibidas
# , lag(mtransferencias_recibidas, 2) OVER ventana_2 AS lag_2_mtransferencias_recibidas
# , mtransferencias_recibidas - lag(mtransferencias_recibidas, 1) OVER ventana_2 AS delta_1_mtransferencias_recibidas
# , mtransferencias_recibidas - lag(mtransferencias_recibidas, 2) OVER ventana_2 AS delta_2_mtransferencias_recibidas
# , lag(ctransferencias_emitidas, 1) OVER ventana_2 AS lag_1_ctransferencias_emitidas
# , lag(ctransferencias_emitidas, 2) OVER ventana_2 AS lag_2_ctransferencias_emitidas
# , ctransferencias_emitidas - lag(ctransferencias_emitidas, 1) OVER ventana_2 AS delta_1_ctransferencias_emitidas
# , ctransferencias_emitidas - lag(ctransferencias_emitidas, 2) OVER ventana_2 AS delta_2_ctransferencias_emitidas
# , lag(mtransferencias_emitidas, 1) OVER ventana_2 AS lag_1_mtransferencias_emitidas
# , lag(mtransferencias_emitidas, 2) OVER ventana_2 AS lag_2_mtransferencias_emitidas
# , mtransferencias_emitidas - lag(mtransferencias_emitidas, 1) OVER ventana_2 AS delta_1_mtransferencias_emitidas
# , mtransferencias_emitidas - lag(mtransferencias_emitidas, 2) OVER ventana_2 AS delta_2_mtransferencias_emitidas
# , lag(cextraccion_autoservicio, 1) OVER ventana_2 AS lag_1_cextraccion_autoservicio
# , lag(cextraccion_autoservicio, 2) OVER ventana_2 AS lag_2_cextraccion_autoservicio
# , cextraccion_autoservicio - lag(cextraccion_autoservicio, 1) OVER ventana_2 AS delta_1_cextraccion_autoservicio
# , cextraccion_autoservicio - lag(cextraccion_autoservicio, 2) OVER ventana_2 AS delta_2_cextraccion_autoservicio
# , lag(mextraccion_autoservicio, 1) OVER ventana_2 AS lag_1_mextraccion_autoservicio
# , lag(mextraccion_autoservicio, 2) OVER ventana_2 AS lag_2_mextraccion_autoservicio
# , mextraccion_autoservicio - lag(mextraccion_autoservicio, 1) OVER ventana_2 AS delta_1_mextraccion_autoservicio
# , mextraccion_autoservicio - lag(mextraccion_autoservicio, 2) OVER ventana_2 AS delta_2_mextraccion_autoservicio
# , lag(ccheques_depositados, 1) OVER ventana_2 AS lag_1_ccheques_depositados
# , lag(ccheques_depositados, 2) OVER ventana_2 AS lag_2_ccheques_depositados
# , ccheques_depositados - lag(ccheques_depositados, 1) OVER ventana_2 AS delta_1_ccheques_depositados
# , ccheques_depositados - lag(ccheques_depositados, 2) OVER ventana_2 AS delta_2_ccheques_depositados
# , lag(mcheques_depositados, 1) OVER ventana_2 AS lag_1_mcheques_depositados
# , lag(mcheques_depositados, 2) OVER ventana_2 AS lag_2_mcheques_depositados
# , mcheques_depositados - lag(mcheques_depositados, 1) OVER ventana_2 AS delta_1_mcheques_depositados
# , mcheques_depositados - lag(mcheques_depositados, 2) OVER ventana_2 AS delta_2_mcheques_depositados
# , lag(ccheques_emitidos, 1) OVER ventana_2 AS lag_1_ccheques_emitidos
# , lag(ccheques_emitidos, 2) OVER ventana_2 AS lag_2_ccheques_emitidos
# , ccheques_emitidos - lag(ccheques_emitidos, 1) OVER ventana_2 AS delta_1_ccheques_emitidos
# , ccheques_emitidos - lag(ccheques_emitidos, 2) OVER ventana_2 AS delta_2_ccheques_emitidos
# , lag(mcheques_emitidos, 1) OVER ventana_2 AS lag_1_mcheques_emitidos
# , lag(mcheques_emitidos, 2) OVER ventana_2 AS lag_2_mcheques_emitidos
# , mcheques_emitidos - lag(mcheques_emitidos, 1) OVER ventana_2 AS delta_1_mcheques_emitidos
# , mcheques_emitidos - lag(mcheques_emitidos, 2) OVER ventana_2 AS delta_2_mcheques_emitidos
# , lag(ccheques_depositados_rechazados, 1) OVER ventana_2 AS lag_1_ccheques_depositados_rechazados
# , lag(ccheques_depositados_rechazados, 2) OVER ventana_2 AS lag_2_ccheques_depositados_rechazados
# , ccheques_depositados_rechazados - lag(ccheques_depositados_rechazados, 1) OVER ventana_2 AS delta_1_ccheques_depositados_rechazados
# , ccheques_depositados_rechazados - lag(ccheques_depositados_rechazados, 2) OVER ventana_2 AS delta_2_ccheques_depositados_rechazados
# , lag(mcheques_depositados_rechazados, 1) OVER ventana_2 AS lag_1_mcheques_depositados_rechazados
# , lag(mcheques_depositados_rechazados, 2) OVER ventana_2 AS lag_2_mcheques_depositados_rechazados
# , mcheques_depositados_rechazados - lag(mcheques_depositados_rechazados, 1) OVER ventana_2 AS delta_1_mcheques_depositados_rechazados
# , mcheques_depositados_rechazados - lag(mcheques_depositados_rechazados, 2) OVER ventana_2 AS delta_2_mcheques_depositados_rechazados
# , lag(ccheques_emitidos_rechazados, 1) OVER ventana_2 AS lag_1_ccheques_emitidos_rechazados
# , lag(ccheques_emitidos_rechazados, 2) OVER ventana_2 AS lag_2_ccheques_emitidos_rechazados
# , ccheques_emitidos_rechazados - lag(ccheques_emitidos_rechazados, 1) OVER ventana_2 AS delta_1_ccheques_emitidos_rechazados
# , ccheques_emitidos_rechazados - lag(ccheques_emitidos_rechazados, 2) OVER ventana_2 AS delta_2_ccheques_emitidos_rechazados
# , lag(mcheques_emitidos_rechazados, 1) OVER ventana_2 AS lag_1_mcheques_emitidos_rechazados
# , lag(mcheques_emitidos_rechazados, 2) OVER ventana_2 AS lag_2_mcheques_emitidos_rechazados
# , mcheques_emitidos_rechazados - lag(mcheques_emitidos_rechazados, 1) OVER ventana_2 AS delta_1_mcheques_emitidos_rechazados
# , mcheques_emitidos_rechazados - lag(mcheques_emitidos_rechazados, 2) OVER ventana_2 AS delta_2_mcheques_emitidos_rechazados
# , lag(tcallcenter, 1) OVER ventana_2 AS lag_1_tcallcenter
# , lag(tcallcenter, 2) OVER ventana_2 AS lag_2_tcallcenter
# , tcallcenter - lag(tcallcenter, 1) OVER ventana_2 AS delta_1_tcallcenter
# , tcallcenter - lag(tcallcenter, 2) OVER ventana_2 AS delta_2_tcallcenter
# , lag(ccallcenter_transacciones, 1) OVER ventana_2 AS lag_1_ccallcenter_transacciones
# , lag(ccallcenter_transacciones, 2) OVER ventana_2 AS lag_2_ccallcenter_transacciones
# , ccallcenter_transacciones - lag(ccallcenter_transacciones, 1) OVER ventana_2 AS delta_1_ccallcenter_transacciones
# , ccallcenter_transacciones - lag(ccallcenter_transacciones, 2) OVER ventana_2 AS delta_2_ccallcenter_transacciones
# , lag(thomebanking, 1) OVER ventana_2 AS lag_1_thomebanking
# , lag(thomebanking, 2) OVER ventana_2 AS lag_2_thomebanking
# , thomebanking - lag(thomebanking, 1) OVER ventana_2 AS delta_1_thomebanking
# , thomebanking - lag(thomebanking, 2) OVER ventana_2 AS delta_2_thomebanking
# , lag(chomebanking_transacciones, 1) OVER ventana_2 AS lag_1_chomebanking_transacciones
# , lag(chomebanking_transacciones, 2) OVER ventana_2 AS lag_2_chomebanking_transacciones
# , chomebanking_transacciones - lag(chomebanking_transacciones, 1) OVER ventana_2 AS delta_1_chomebanking_transacciones
# , chomebanking_transacciones - lag(chomebanking_transacciones, 2) OVER ventana_2 AS delta_2_chomebanking_transacciones
# , lag(ccajas_transacciones, 1) OVER ventana_2 AS lag_1_ccajas_transacciones
# , lag(ccajas_transacciones, 2) OVER ventana_2 AS lag_2_ccajas_transacciones
# , ccajas_transacciones - lag(ccajas_transacciones, 1) OVER ventana_2 AS delta_1_ccajas_transacciones
# , ccajas_transacciones - lag(ccajas_transacciones, 2) OVER ventana_2 AS delta_2_ccajas_transacciones
# , lag(ccajas_consultas, 1) OVER ventana_2 AS lag_1_ccajas_consultas
# , lag(ccajas_consultas, 2) OVER ventana_2 AS lag_2_ccajas_consultas
# , ccajas_consultas - lag(ccajas_consultas, 1) OVER ventana_2 AS delta_1_ccajas_consultas
# , ccajas_consultas - lag(ccajas_consultas, 2) OVER ventana_2 AS delta_2_ccajas_consultas
# , lag(ccajas_depositos, 1) OVER ventana_2 AS lag_1_ccajas_depositos
# , lag(ccajas_depositos, 2) OVER ventana_2 AS lag_2_ccajas_depositos
# , ccajas_depositos - lag(ccajas_depositos, 1) OVER ventana_2 AS delta_1_ccajas_depositos
# , ccajas_depositos - lag(ccajas_depositos, 2) OVER ventana_2 AS delta_2_ccajas_depositos
# , lag(ccajas_extracciones, 1) OVER ventana_2 AS lag_1_ccajas_extracciones
# , lag(ccajas_extracciones, 2) OVER ventana_2 AS lag_2_ccajas_extracciones
# , ccajas_extracciones - lag(ccajas_extracciones, 1) OVER ventana_2 AS delta_1_ccajas_extracciones
# , ccajas_extracciones - lag(ccajas_extracciones, 2) OVER ventana_2 AS delta_2_ccajas_extracciones
# , lag(ccajas_otras, 1) OVER ventana_2 AS lag_1_ccajas_otras
# , lag(ccajas_otras, 2) OVER ventana_2 AS lag_2_ccajas_otras
# , ccajas_otras - lag(ccajas_otras, 1) OVER ventana_2 AS delta_1_ccajas_otras
# , ccajas_otras - lag(ccajas_otras, 2) OVER ventana_2 AS delta_2_ccajas_otras
# , lag(catm_trx, 1) OVER ventana_2 AS lag_1_catm_trx
# , lag(catm_trx, 2) OVER ventana_2 AS lag_2_catm_trx
# , catm_trx - lag(catm_trx, 1) OVER ventana_2 AS delta_1_catm_trx
# , catm_trx - lag(catm_trx, 2) OVER ventana_2 AS delta_2_catm_trx
# , lag(matm, 1) OVER ventana_2 AS lag_1_matm
# , lag(matm, 2) OVER ventana_2 AS lag_2_matm
# , matm - lag(matm, 1) OVER ventana_2 AS delta_1_matm
# , matm - lag(matm, 2) OVER ventana_2 AS delta_2_matm
# , lag(catm_trx_other, 1) OVER ventana_2 AS lag_1_catm_trx_other
# , lag(catm_trx_other, 2) OVER ventana_2 AS lag_2_catm_trx_other
# , catm_trx_other - lag(catm_trx_other, 1) OVER ventana_2 AS delta_1_catm_trx_other
# , catm_trx_other - lag(catm_trx_other, 2) OVER ventana_2 AS delta_2_catm_trx_other
# , lag(matm_other, 1) OVER ventana_2 AS lag_1_matm_other
# , lag(matm_other, 2) OVER ventana_2 AS lag_2_matm_other
# , matm_other - lag(matm_other, 1) OVER ventana_2 AS delta_1_matm_other
# , matm_other - lag(matm_other, 2) OVER ventana_2 AS delta_2_matm_other
# , lag(ctrx_quarter, 1) OVER ventana_2 AS lag_1_ctrx_quarter
# , lag(ctrx_quarter, 2) OVER ventana_2 AS lag_2_ctrx_quarter
# , ctrx_quarter - lag(ctrx_quarter, 1) OVER ventana_2 AS delta_1_ctrx_quarter
# , ctrx_quarter - lag(ctrx_quarter, 2) OVER ventana_2 AS delta_2_ctrx_quarter
# , lag(tmobile_app, 1) OVER ventana_2 AS lag_1_tmobile_app
# , lag(tmobile_app, 2) OVER ventana_2 AS lag_2_tmobile_app
# , tmobile_app - lag(tmobile_app, 1) OVER ventana_2 AS delta_1_tmobile_app
# , tmobile_app - lag(tmobile_app, 2) OVER ventana_2 AS delta_2_tmobile_app
# , lag(cmobile_app_trx, 1) OVER ventana_2 AS lag_1_cmobile_app_trx
# , lag(cmobile_app_trx, 2) OVER ventana_2 AS lag_2_cmobile_app_trx
# , cmobile_app_trx - lag(cmobile_app_trx, 1) OVER ventana_2 AS delta_1_cmobile_app_trx
# , cmobile_app_trx - lag(cmobile_app_trx, 2) OVER ventana_2 AS delta_2_cmobile_app_trx
# , lag(Master_delinquency, 1) OVER ventana_2 AS lag_1_Master_delinquency
# , lag(Master_delinquency, 2) OVER ventana_2 AS lag_2_Master_delinquency
# , Master_delinquency - lag(Master_delinquency, 1) OVER ventana_2 AS delta_1_Master_delinquency
# , Master_delinquency - lag(Master_delinquency, 2) OVER ventana_2 AS delta_2_Master_delinquency
# , lag(Master_status, 1) OVER ventana_2 AS lag_1_Master_status
# , lag(Master_status, 2) OVER ventana_2 AS lag_2_Master_status
# , Master_status - lag(Master_status, 1) OVER ventana_2 AS delta_1_Master_status
# , Master_status - lag(Master_status, 2) OVER ventana_2 AS delta_2_Master_status
# , lag(Master_mfinanciacion_limite, 1) OVER ventana_2 AS lag_1_Master_mfinanciacion_limite
# , lag(Master_mfinanciacion_limite, 2) OVER ventana_2 AS lag_2_Master_mfinanciacion_limite
# , Master_mfinanciacion_limite - lag(Master_mfinanciacion_limite, 1) OVER ventana_2 AS delta_1_Master_mfinanciacion_limite
# , Master_mfinanciacion_limite - lag(Master_mfinanciacion_limite, 2) OVER ventana_2 AS delta_2_Master_mfinanciacion_limite
# , lag(Master_Fvencimiento, 1) OVER ventana_2 AS lag_1_Master_Fvencimiento
# , lag(Master_Fvencimiento, 2) OVER ventana_2 AS lag_2_Master_Fvencimiento
# , Master_Fvencimiento - lag(Master_Fvencimiento, 1) OVER ventana_2 AS delta_1_Master_Fvencimiento
# , Master_Fvencimiento - lag(Master_Fvencimiento, 2) OVER ventana_2 AS delta_2_Master_Fvencimiento
# , lag(Master_Finiciomora, 1) OVER ventana_2 AS lag_1_Master_Finiciomora
# , lag(Master_Finiciomora, 2) OVER ventana_2 AS lag_2_Master_Finiciomora
# , Master_Finiciomora - lag(Master_Finiciomora, 1) OVER ventana_2 AS delta_1_Master_Finiciomora
# , Master_Finiciomora - lag(Master_Finiciomora, 2) OVER ventana_2 AS delta_2_Master_Finiciomora
# , lag(Master_msaldototal, 1) OVER ventana_2 AS lag_1_Master_msaldototal
# , lag(Master_msaldototal, 2) OVER ventana_2 AS lag_2_Master_msaldototal
# , Master_msaldototal - lag(Master_msaldototal, 1) OVER ventana_2 AS delta_1_Master_msaldototal
# , Master_msaldototal - lag(Master_msaldototal, 2) OVER ventana_2 AS delta_2_Master_msaldototal
# , lag(Master_msaldopesos, 1) OVER ventana_2 AS lag_1_Master_msaldopesos
# , lag(Master_msaldopesos, 2) OVER ventana_2 AS lag_2_Master_msaldopesos
# , Master_msaldopesos - lag(Master_msaldopesos, 1) OVER ventana_2 AS delta_1_Master_msaldopesos
# , Master_msaldopesos - lag(Master_msaldopesos, 2) OVER ventana_2 AS delta_2_Master_msaldopesos
# , lag(Master_msaldodolares, 1) OVER ventana_2 AS lag_1_Master_msaldodolares
# , lag(Master_msaldodolares, 2) OVER ventana_2 AS lag_2_Master_msaldodolares
# , Master_msaldodolares - lag(Master_msaldodolares, 1) OVER ventana_2 AS delta_1_Master_msaldodolares
# , Master_msaldodolares - lag(Master_msaldodolares, 2) OVER ventana_2 AS delta_2_Master_msaldodolares
# , lag(Master_mconsumospesos, 1) OVER ventana_2 AS lag_1_Master_mconsumospesos
# , lag(Master_mconsumospesos, 2) OVER ventana_2 AS lag_2_Master_mconsumospesos
# , Master_mconsumospesos - lag(Master_mconsumospesos, 1) OVER ventana_2 AS delta_1_Master_mconsumospesos
# , Master_mconsumospesos - lag(Master_mconsumospesos, 2) OVER ventana_2 AS delta_2_Master_mconsumospesos
# , lag(Master_mconsumosdolares, 1) OVER ventana_2 AS lag_1_Master_mconsumosdolares
# , lag(Master_mconsumosdolares, 2) OVER ventana_2 AS lag_2_Master_mconsumosdolares
# , Master_mconsumosdolares - lag(Master_mconsumosdolares, 1) OVER ventana_2 AS delta_1_Master_mconsumosdolares
# , Master_mconsumosdolares - lag(Master_mconsumosdolares, 2) OVER ventana_2 AS delta_2_Master_mconsumosdolares
# , lag(Master_mlimitecompra, 1) OVER ventana_2 AS lag_1_Master_mlimitecompra
# , lag(Master_mlimitecompra, 2) OVER ventana_2 AS lag_2_Master_mlimitecompra
# , Master_mlimitecompra - lag(Master_mlimitecompra, 1) OVER ventana_2 AS delta_1_Master_mlimitecompra
# , Master_mlimitecompra - lag(Master_mlimitecompra, 2) OVER ventana_2 AS delta_2_Master_mlimitecompra
# , lag(Master_madelantopesos, 1) OVER ventana_2 AS lag_1_Master_madelantopesos
# , lag(Master_madelantopesos, 2) OVER ventana_2 AS lag_2_Master_madelantopesos
# , Master_madelantopesos - lag(Master_madelantopesos, 1) OVER ventana_2 AS delta_1_Master_madelantopesos
# , Master_madelantopesos - lag(Master_madelantopesos, 2) OVER ventana_2 AS delta_2_Master_madelantopesos
# , lag(Master_madelantodolares, 1) OVER ventana_2 AS lag_1_Master_madelantodolares
# , lag(Master_madelantodolares, 2) OVER ventana_2 AS lag_2_Master_madelantodolares
# , Master_madelantodolares - lag(Master_madelantodolares, 1) OVER ventana_2 AS delta_1_Master_madelantodolares
# , Master_madelantodolares - lag(Master_madelantodolares, 2) OVER ventana_2 AS delta_2_Master_madelantodolares
# , lag(Master_fultimo_cierre, 1) OVER ventana_2 AS lag_1_Master_fultimo_cierre
# , lag(Master_fultimo_cierre, 2) OVER ventana_2 AS lag_2_Master_fultimo_cierre
# , Master_fultimo_cierre - lag(Master_fultimo_cierre, 1) OVER ventana_2 AS delta_1_Master_fultimo_cierre
# , Master_fultimo_cierre - lag(Master_fultimo_cierre, 2) OVER ventana_2 AS delta_2_Master_fultimo_cierre
# , lag(Master_mpagado, 1) OVER ventana_2 AS lag_1_Master_mpagado
# , lag(Master_mpagado, 2) OVER ventana_2 AS lag_2_Master_mpagado
# , Master_mpagado - lag(Master_mpagado, 1) OVER ventana_2 AS delta_1_Master_mpagado
# , Master_mpagado - lag(Master_mpagado, 2) OVER ventana_2 AS delta_2_Master_mpagado
# , lag(Master_mpagospesos, 1) OVER ventana_2 AS lag_1_Master_mpagospesos
# , lag(Master_mpagospesos, 2) OVER ventana_2 AS lag_2_Master_mpagospesos
# , Master_mpagospesos - lag(Master_mpagospesos, 1) OVER ventana_2 AS delta_1_Master_mpagospesos
# , Master_mpagospesos - lag(Master_mpagospesos, 2) OVER ventana_2 AS delta_2_Master_mpagospesos
# , lag(Master_mpagosdolares, 1) OVER ventana_2 AS lag_1_Master_mpagosdolares
# , lag(Master_mpagosdolares, 2) OVER ventana_2 AS lag_2_Master_mpagosdolares
# , Master_mpagosdolares - lag(Master_mpagosdolares, 1) OVER ventana_2 AS delta_1_Master_mpagosdolares
# , Master_mpagosdolares - lag(Master_mpagosdolares, 2) OVER ventana_2 AS delta_2_Master_mpagosdolares
# , lag(Master_fechaalta, 1) OVER ventana_2 AS lag_1_Master_fechaalta
# , lag(Master_fechaalta, 2) OVER ventana_2 AS lag_2_Master_fechaalta
# , Master_fechaalta - lag(Master_fechaalta, 1) OVER ventana_2 AS delta_1_Master_fechaalta
# , Master_fechaalta - lag(Master_fechaalta, 2) OVER ventana_2 AS delta_2_Master_fechaalta
# , lag(Master_mconsumototal, 1) OVER ventana_2 AS lag_1_Master_mconsumototal
# , lag(Master_mconsumototal, 2) OVER ventana_2 AS lag_2_Master_mconsumototal
# , Master_mconsumototal - lag(Master_mconsumototal, 1) OVER ventana_2 AS delta_1_Master_mconsumototal
# , Master_mconsumototal - lag(Master_mconsumototal, 2) OVER ventana_2 AS delta_2_Master_mconsumototal
# , lag(Master_cconsumos, 1) OVER ventana_2 AS lag_1_Master_cconsumos
# , lag(Master_cconsumos, 2) OVER ventana_2 AS lag_2_Master_cconsumos
# , Master_cconsumos - lag(Master_cconsumos, 1) OVER ventana_2 AS delta_1_Master_cconsumos
# , Master_cconsumos - lag(Master_cconsumos, 2) OVER ventana_2 AS delta_2_Master_cconsumos
# , lag(Master_cadelantosefectivo, 1) OVER ventana_2 AS lag_1_Master_cadelantosefectivo
# , lag(Master_cadelantosefectivo, 2) OVER ventana_2 AS lag_2_Master_cadelantosefectivo
# , Master_cadelantosefectivo - lag(Master_cadelantosefectivo, 1) OVER ventana_2 AS delta_1_Master_cadelantosefectivo
# , Master_cadelantosefectivo - lag(Master_cadelantosefectivo, 2) OVER ventana_2 AS delta_2_Master_cadelantosefectivo
# , lag(Master_mpagominimo, 1) OVER ventana_2 AS lag_1_Master_mpagominimo
# , lag(Master_mpagominimo, 2) OVER ventana_2 AS lag_2_Master_mpagominimo
# , Master_mpagominimo - lag(Master_mpagominimo, 1) OVER ventana_2 AS delta_1_Master_mpagominimo
# , Master_mpagominimo - lag(Master_mpagominimo, 2) OVER ventana_2 AS delta_2_Master_mpagominimo
# , lag(Visa_delinquency, 1) OVER ventana_2 AS lag_1_Visa_delinquency
# , lag(Visa_delinquency, 2) OVER ventana_2 AS lag_2_Visa_delinquency
# , Visa_delinquency - lag(Visa_delinquency, 1) OVER ventana_2 AS delta_1_Visa_delinquency
# , Visa_delinquency - lag(Visa_delinquency, 2) OVER ventana_2 AS delta_2_Visa_delinquency
# , lag(Visa_status, 1) OVER ventana_2 AS lag_1_Visa_status
# , lag(Visa_status, 2) OVER ventana_2 AS lag_2_Visa_status
# , Visa_status - lag(Visa_status, 1) OVER ventana_2 AS delta_1_Visa_status
# , Visa_status - lag(Visa_status, 2) OVER ventana_2 AS delta_2_Visa_status
# , lag(Visa_mfinanciacion_limite, 1) OVER ventana_2 AS lag_1_Visa_mfinanciacion_limite
# , lag(Visa_mfinanciacion_limite, 2) OVER ventana_2 AS lag_2_Visa_mfinanciacion_limite
# , Visa_mfinanciacion_limite - lag(Visa_mfinanciacion_limite, 1) OVER ventana_2 AS delta_1_Visa_mfinanciacion_limite
# , Visa_mfinanciacion_limite - lag(Visa_mfinanciacion_limite, 2) OVER ventana_2 AS delta_2_Visa_mfinanciacion_limite
# , lag(Visa_Fvencimiento, 1) OVER ventana_2 AS lag_1_Visa_Fvencimiento
# , lag(Visa_Fvencimiento, 2) OVER ventana_2 AS lag_2_Visa_Fvencimiento
# , Visa_Fvencimiento - lag(Visa_Fvencimiento, 1) OVER ventana_2 AS delta_1_Visa_Fvencimiento
# , Visa_Fvencimiento - lag(Visa_Fvencimiento, 2) OVER ventana_2 AS delta_2_Visa_Fvencimiento
# , lag(Visa_Finiciomora, 1) OVER ventana_2 AS lag_1_Visa_Finiciomora
# , lag(Visa_Finiciomora, 2) OVER ventana_2 AS lag_2_Visa_Finiciomora
# , Visa_Finiciomora - lag(Visa_Finiciomora, 1) OVER ventana_2 AS delta_1_Visa_Finiciomora
# , Visa_Finiciomora - lag(Visa_Finiciomora, 2) OVER ventana_2 AS delta_2_Visa_Finiciomora
# , lag(Visa_msaldototal, 1) OVER ventana_2 AS lag_1_Visa_msaldototal
# , lag(Visa_msaldototal, 2) OVER ventana_2 AS lag_2_Visa_msaldototal
# , Visa_msaldototal - lag(Visa_msaldototal, 1) OVER ventana_2 AS delta_1_Visa_msaldototal
# , Visa_msaldototal - lag(Visa_msaldototal, 2) OVER ventana_2 AS delta_2_Visa_msaldototal
# , lag(Visa_msaldopesos, 1) OVER ventana_2 AS lag_1_Visa_msaldopesos
# , lag(Visa_msaldopesos, 2) OVER ventana_2 AS lag_2_Visa_msaldopesos
# , Visa_msaldopesos - lag(Visa_msaldopesos, 1) OVER ventana_2 AS delta_1_Visa_msaldopesos
# , Visa_msaldopesos - lag(Visa_msaldopesos, 2) OVER ventana_2 AS delta_2_Visa_msaldopesos
# , lag(Visa_msaldodolares, 1) OVER ventana_2 AS lag_1_Visa_msaldodolares
# , lag(Visa_msaldodolares, 2) OVER ventana_2 AS lag_2_Visa_msaldodolares
# , Visa_msaldodolares - lag(Visa_msaldodolares, 1) OVER ventana_2 AS delta_1_Visa_msaldodolares
# , Visa_msaldodolares - lag(Visa_msaldodolares, 2) OVER ventana_2 AS delta_2_Visa_msaldodolares
# , lag(Visa_mconsumospesos, 1) OVER ventana_2 AS lag_1_Visa_mconsumospesos
# , lag(Visa_mconsumospesos, 2) OVER ventana_2 AS lag_2_Visa_mconsumospesos
# , Visa_mconsumospesos - lag(Visa_mconsumospesos, 1) OVER ventana_2 AS delta_1_Visa_mconsumospesos
# , Visa_mconsumospesos - lag(Visa_mconsumospesos, 2) OVER ventana_2 AS delta_2_Visa_mconsumospesos
# , lag(Visa_mconsumosdolares, 1) OVER ventana_2 AS lag_1_Visa_mconsumosdolares
# , lag(Visa_mconsumosdolares, 2) OVER ventana_2 AS lag_2_Visa_mconsumosdolares
# , Visa_mconsumosdolares - lag(Visa_mconsumosdolares, 1) OVER ventana_2 AS delta_1_Visa_mconsumosdolares
# , Visa_mconsumosdolares - lag(Visa_mconsumosdolares, 2) OVER ventana_2 AS delta_2_Visa_mconsumosdolares
# , lag(Visa_mlimitecompra, 1) OVER ventana_2 AS lag_1_Visa_mlimitecompra
# , lag(Visa_mlimitecompra, 2) OVER ventana_2 AS lag_2_Visa_mlimitecompra
# , Visa_mlimitecompra - lag(Visa_mlimitecompra, 1) OVER ventana_2 AS delta_1_Visa_mlimitecompra
# , Visa_mlimitecompra - lag(Visa_mlimitecompra, 2) OVER ventana_2 AS delta_2_Visa_mlimitecompra
# , lag(Visa_madelantopesos, 1) OVER ventana_2 AS lag_1_Visa_madelantopesos
# , lag(Visa_madelantopesos, 2) OVER ventana_2 AS lag_2_Visa_madelantopesos
# , Visa_madelantopesos - lag(Visa_madelantopesos, 1) OVER ventana_2 AS delta_1_Visa_madelantopesos
# , Visa_madelantopesos - lag(Visa_madelantopesos, 2) OVER ventana_2 AS delta_2_Visa_madelantopesos
# , lag(Visa_madelantodolares, 1) OVER ventana_2 AS lag_1_Visa_madelantodolares
# , lag(Visa_madelantodolares, 2) OVER ventana_2 AS lag_2_Visa_madelantodolares
# , Visa_madelantodolares - lag(Visa_madelantodolares, 1) OVER ventana_2 AS delta_1_Visa_madelantodolares
# , Visa_madelantodolares - lag(Visa_madelantodolares, 2) OVER ventana_2 AS delta_2_Visa_madelantodolares
# , lag(Visa_fultimo_cierre, 1) OVER ventana_2 AS lag_1_Visa_fultimo_cierre
# , lag(Visa_fultimo_cierre, 2) OVER ventana_2 AS lag_2_Visa_fultimo_cierre
# , Visa_fultimo_cierre - lag(Visa_fultimo_cierre, 1) OVER ventana_2 AS delta_1_Visa_fultimo_cierre
# , Visa_fultimo_cierre - lag(Visa_fultimo_cierre, 2) OVER ventana_2 AS delta_2_Visa_fultimo_cierre
# , lag(Visa_mpagado, 1) OVER ventana_2 AS lag_1_Visa_mpagado
# , lag(Visa_mpagado, 2) OVER ventana_2 AS lag_2_Visa_mpagado
# , Visa_mpagado - lag(Visa_mpagado, 1) OVER ventana_2 AS delta_1_Visa_mpagado
# , Visa_mpagado - lag(Visa_mpagado, 2) OVER ventana_2 AS delta_2_Visa_mpagado
# , lag(Visa_mpagospesos, 1) OVER ventana_2 AS lag_1_Visa_mpagospesos
# , lag(Visa_mpagospesos, 2) OVER ventana_2 AS lag_2_Visa_mpagospesos
# , Visa_mpagospesos - lag(Visa_mpagospesos, 1) OVER ventana_2 AS delta_1_Visa_mpagospesos
# , Visa_mpagospesos - lag(Visa_mpagospesos, 2) OVER ventana_2 AS delta_2_Visa_mpagospesos
# , lag(Visa_mpagosdolares, 1) OVER ventana_2 AS lag_1_Visa_mpagosdolares
# , lag(Visa_mpagosdolares, 2) OVER ventana_2 AS lag_2_Visa_mpagosdolares
# , Visa_mpagosdolares - lag(Visa_mpagosdolares, 1) OVER ventana_2 AS delta_1_Visa_mpagosdolares
# , Visa_mpagosdolares - lag(Visa_mpagosdolares, 2) OVER ventana_2 AS delta_2_Visa_mpagosdolares
# , lag(Visa_fechaalta, 1) OVER ventana_2 AS lag_1_Visa_fechaalta
# , lag(Visa_fechaalta, 2) OVER ventana_2 AS lag_2_Visa_fechaalta
# , Visa_fechaalta - lag(Visa_fechaalta, 1) OVER ventana_2 AS delta_1_Visa_fechaalta
# , Visa_fechaalta - lag(Visa_fechaalta, 2) OVER ventana_2 AS delta_2_Visa_fechaalta
# , lag(Visa_mconsumototal, 1) OVER ventana_2 AS lag_1_Visa_mconsumototal
# , lag(Visa_mconsumototal, 2) OVER ventana_2 AS lag_2_Visa_mconsumototal
# , Visa_mconsumototal - lag(Visa_mconsumototal, 1) OVER ventana_2 AS delta_1_Visa_mconsumototal
# , Visa_mconsumototal - lag(Visa_mconsumototal, 2) OVER ventana_2 AS delta_2_Visa_mconsumototal
# , lag(Visa_cconsumos, 1) OVER ventana_2 AS lag_1_Visa_cconsumos
# , lag(Visa_cconsumos, 2) OVER ventana_2 AS lag_2_Visa_cconsumos
# , Visa_cconsumos - lag(Visa_cconsumos, 1) OVER ventana_2 AS delta_1_Visa_cconsumos
# , Visa_cconsumos - lag(Visa_cconsumos, 2) OVER ventana_2 AS delta_2_Visa_cconsumos
# , lag(Visa_cadelantosefectivo, 1) OVER ventana_2 AS lag_1_Visa_cadelantosefectivo
# , lag(Visa_cadelantosefectivo, 2) OVER ventana_2 AS lag_2_Visa_cadelantosefectivo
# , Visa_cadelantosefectivo - lag(Visa_cadelantosefectivo, 1) OVER ventana_2 AS delta_1_Visa_cadelantosefectivo
# , Visa_cadelantosefectivo - lag(Visa_cadelantosefectivo, 2) OVER ventana_2 AS delta_2_Visa_cadelantosefectivo
# , lag(Visa_mpagominimo, 1) OVER ventana_2 AS lag_1_Visa_mpagominimo
# , lag(Visa_mpagominimo, 2) OVER ventana_2 AS lag_2_Visa_mpagominimo
# , Visa_mpagominimo - lag(Visa_mpagominimo, 1) OVER ventana_2 AS delta_1_Visa_mpagominimo
# , Visa_mpagominimo - lag(Visa_mpagominimo, 2) OVER ventana_2 AS delta_2_Visa_mpagominimo
#   FROM competencia_01
#   WINDOW ventana_2 AS (
#     PARTITION BY numero_de_cliente
#     ORDER BY foto_mes
#     ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
#   )
# ) TO 'delta_lags_12.csv' (FORMAT CSV, HEADER TRUE)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [Success]
# Index: []
